# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from collections import Counter


import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Subset, Dataset, DataLoader
import torch.optim as optim

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Model Class implementation and training function

# %%
class EEGNet(nn.Module):
    def __init__(self, num_classes=7, num_channels=24, input_samples=1500, dropout_rate=0.25, kernel_length=64, F1=8, D=2, F2=16):
        super(EEGNet, self).__init__()

        self.num_classes = num_classes

        self.firstConv = nn.Sequential(
            nn.Conv2d(1, F1, kernel_size=(1,kernel_length), padding=(0, kernel_length//2), bias=False),
            nn.BatchNorm2d(F1)
        )

        self.depthwiseConv = nn.Sequential(
            nn.Conv2d(F1, F1*D, kernel_size=(num_channels, 1), groups=F1, bias=False),
            nn.BatchNorm2d(F1*D),
            nn.ELU(),
            nn.AvgPool2d(kernel_size=(1,4)),
            nn.Dropout(p=dropout_rate)
        )

        self.separableConv = nn.Sequential(
            nn.Conv2d(F1*D, F2, kernel_size=(1,16), padding=(0,8), bias=False),
            nn.BatchNorm2d(F2),
            nn.ELU(),
            nn.AvgPool2d(kernel_size=(1,8)),
            nn.Dropout(p=dropout_rate)
        )

        with torch.no_grad():
            dummy = torch.zeros(1, 1, num_channels, input_samples)
            x = self.firstConv(dummy)
            x = self.depthwiseConv(x)
            x = self.separableConv(x)
            # print (x.shape)
            flattened = x.shape[1] * x.shape[2] * x.shape[3]


        self.classify = nn.Sequential(
            nn.Flatten(),
            nn.Linear(flattened, num_classes)
        )

    def forward(self, x):
        x = self.firstConv(x)
        x = self.depthwiseConv(x)
        x = self.separableConv(x)
        x = self.classify(x)
        return x

# %%
# Train and evaluate
def train(model, train_loader, criterion, optimizer, device):
    model.train()
    total_loss = 0

    for X,y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(X)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    return total_loss / len(train_loader)

def evaluate(model, test_loader, device):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for X, y in test_loader:
            X,y = X.to(device), y.to(device)
            out = model(X)
            pred = out.argmax(dim=1)  # FIXED: Changed from argmin to argmax

            correct += (pred == y).sum().item()
            total += y.size(0)

    return correct / total

def evaluateFinal(model, test_loader, device):
    model.eval()
    correct, total = 0, 0

    actual = torch.tensor([])
    predicted = torch.tensor([])
    with torch.no_grad():
        for X, y in test_loader:
            X,y = X.to(device), y.to(device)
            out = model(X)
            pred = out.argmax(dim=1)  # FIXED: Changed from argmin to argmax

            correct += (pred == y).sum().item()
            total += y.size(0)

            actual = torch.cat((actual, y.cpu()), dim=0)
            predicted = torch.cat((predicted, pred.cpu()), dim=0)

        print(np.unique(predicted.numpy(), return_counts=True))

        cm = confusion_matrix(actual.numpy(), predicted.numpy())
        ConfusionMatrixDisplay(cm).plot()

    print(f"The accuracy for the test is {(correct / total)*100:.2f}%")

    return correct / total

# %%
# DataLoader with proper data type handling

class BCIDataset(Dataset):
    def __init__(self, X, y):
        # Ensure proper data types to avoid kernel crashes
        # X should be float32, y should be int64 (long)
        self.X = torch.from_numpy(X.astype(np.float32))
        self.y = torch.from_numpy(y.astype(np.int64))

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %% [markdown]
# # Load the data
#
# The first thing we need to do is to load the data from our input file and check its content to make suure that we are aactually loading complete data

# %%
def load_data_method_1(file_path):
    """
    Original method - iterates gesture_type then row
    """
    mat_file = scipy.io.loadmat(file_path)
    cell_array = mat_file["combinedCell"]
    # print(mat_file.keys())

    X, Y = [], []
    num_classes = cell_array.shape[1]
    num_training_ex = cell_array.shape[0]

    print("num_classes", num_classes)
    print("num_training_ex", num_training_ex)

    for gesture_type in range(num_classes):
        for row_idx in range(num_training_ex):
            cell = cell_array[row_idx, gesture_type]
            cell = np.array(cell)
            X.append(cell.astype(np.float32))
            Y.append(gesture_type)

    return np.array(X), np.array(Y)

# %%
# Load the .mat file
# file_path = "E:/Chris/EMG/Data/put_emg_model_data.mat"
# file_path = '/Users/chrisdollo/Documents/Research/putEMG prime/Data/combined_per_per_subject/uniformized_emg_gestures_03_combined_non_uniform.mat'
# file_path = '/Users/chrisdollo/Documents/Research/putEMG prime/Data/data_5_subjects/total/data_for_5_subject.mat'

file_path = '/Users/chrisdollo/Documents/Research/putEMG prime/Data/X/model_ready_5/model_ready_5_sub.mat'


# parttial dataset
#file_path = "E:/Chris/EMG/Data/put_emg_model_data.mat"
# file_path = "E:/Chris/EMG/Data/data_for_5_subject.mat"
# file_path = "E:/Chris/EMG/Data/uniform_mat_data_per_subject/uniformized_emg_gestures_15_combined_non_uniform.mat"
# file_path="E:/Chris/EMG/Data/uniform_mat_data_per_subject/uniformized_emg_gestures_20_combined_non_uniform.mat"

X, Y = load_data_method_1(file_path)
# Out:
# num_classes 7
# num_training_ex 200

# %%
# checking for unique values
print(f"X shape: {X.shape}")
print(f"y shape: {Y.shape}")
print(f"Those are the unique label values {np.unique(Y, return_counts=True)}")
# Out:
# X shape: (1400, 1500, 24)
# y shape: (1400,)
# Those are the unique label values (array([0, 1, 2, 3, 4, 5, 6]), array([200, 200, 200, 200, 200, 200, 200]))

# %% [markdown]
# 2. Prepare the data for training
#
# Here we need to get the data in a format that works with our model.
# Our model takes on 4-Dimensional input so we need to add a new dimension to our training example.
#
# We then need to split the data in training and testing set. We'll do 20% for testing and 80% for training
#
# Finally, we need to pass the data to our pre-define data loaders so that it can be used to train the model

# %%
# adding an extra dimention to our training example
X = X[:, np.newaxis, :, :]
X = np.transpose(X, (0, 1, 3, 2))

Y= Y.squeeze()
Y = Y.astype(np.int64)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, stratify=Y, random_state=42)

train_ds = BCIDataset(X_train,y_train)

# %%
labels = {}
for i in y_test:
    if i in labels:
        labels[i] +=1
    else:
        labels[i]=1
print(labels)
# Out:
# {np.int64(5): 40, np.int64(1): 40, np.int64(3): 40, np.int64(6): 40, np.int64(2): 40, np.int64(0): 40, np.int64(4): 40}

# %% [markdown]
# # Model validation and Training
#
# Now we can create the model and start training

# %%
# Set up for cross validation
K = 5
skf = StratifiedKFold(n_splits = K, shuffle=True, random_state=42)
indices = np.arange(len(train_ds))


# Hyperparameters to try to fine-tune the data
# dropouts = [i/100 for i in range(10, 50, 10)]
# learning_rates = [i/1000 for i in range(5, 125, 25)]
dropouts = [0.1]
learning_rates = [1e-3]
dropouts = [0.1, 0.2, 0.3]
# learning_rates = [5e-4, 1e-4, 3e-4, 1e-3]

# %%
def create_mod(train_loader, val_loader, learning_rate, dropout_rate, device):

    # initialize the model with the dropout rate and the learning rate
    model = EEGNet(num_classes= 7, num_channels=24, input_samples=1500, dropout_rate=dropout_rate)
    model = model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    # stats variable
    max_epochs = 15
    patience = 7
    min_delta = 0.005

    true_best = float("-inf")   # strict best (any improvement)
    es_best   = float("-inf")   # meaningful best (improvement >= min_delta)
    mx_acc_model = 0
    bad_epochs = 0
    epochs = 0

    # training loop
    while(epochs < max_epochs):
        
        loss = train(model, train_loader, criterion, optimizer, device)
        acc = evaluate(model, val_loader, device)

        if acc > true_best:
            true_best = acc

        if acc > (es_best + min_delta):
            es_best = acc
            bad_epochs = 0
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            bad_epochs += 1 
            
        print(f"Epoch {epochs}: Loss= {loss:.4f}, Accuracy: {acc*100:.2f}%, Max Acc: {mx_acc_model*100:.2f} "
              f"TrueBest={true_best*100:.2f}%, ESBest={es_best*100:.2f}%, "
            )

        if bad_epochs >= patience:
            print("Stopping Early ....")
            break 

        epochs+=1
    

    return es_best

# %%
max_accuracy = 0
best_model_weights = None
best_lr = 0
best_dropout = 0


for lr in learning_rates:
    for dropout in dropouts:

        fold_acc = []               # keeps track of all accuracies got for the fold
        best_acc_for_lr_dr = 0      # keeps track of best accuracy for a specific combination of learning rate and dropout

        # we create set up the different folds
        for fold, (train_idx, val_idx) in enumerate(skf.split(indices, y_train), 1):

            # print(f"Fold {fold}, dropout:{dropout}, lr = {lr}")

            # for each fold we use part of our set as training set and the other part as validation
            train_subset = Subset(train_ds, train_idx)
            val_subset = Subset(train_ds, val_idx)

            train_loader = DataLoader(train_subset, batch_size=16, shuffle=True)
            val_loader = DataLoader(val_subset, batch_size=16, shuffle=False)

            # training function
            accuracy_for_lr_dr_fld = create_mod(train_loader, val_loader, lr, dropout, device)
            fold_acc.append(accuracy_for_lr_dr_fld)
            

            if accuracy_for_lr_dr_fld > best_acc_for_lr_dr:
                best_acc_for_lr_dr = accuracy_for_lr_dr_fld
        
        mean_fold_acc = np.mean(fold_acc)
        
        if mean_fold_acc > max_accuracy:
            print("Better hyperparameters found")
            best_dropout = dropout
            best_lr = lr
            max_accuracy = mean_fold_acc

        print("--------------")
        print(f"Best accuracy for combo of learning rate and dropout = {best_acc_for_lr_dr}")
        print(f"Accuracies for the entire fold {fold_acc}")
        print(f"Mean accuracy for the fold {mean_fold_acc}")
        print("--------------")
# Out:
# Epoch 0: Loss= 1.7822, Accuracy: 29.91%, Max Acc: 0.00 TrueBest=29.91%, ESBest=29.91%,
# Epoch 1: Loss= 1.3989, Accuracy: 44.64%, Max Acc: 0.00 TrueBest=44.64%, ESBest=44.64%,
# Epoch 2: Loss= 1.1618, Accuracy: 55.36%, Max Acc: 0.00 TrueBest=55.36%, ESBest=55.36%,
# Epoch 3: Loss= 1.0094, Accuracy: 61.61%, Max Acc: 0.00 TrueBest=61.61%, ESBest=61.61%,
# Epoch 4: Loss= 0.9108, Accuracy: 58.48%, Max Acc: 0.00 TrueBest=61.61%, ESBest=61.61%,
# Epoch 5: Loss= 0.8506, Accuracy: 60.71%, Max Acc: 0.00 TrueBest=61.61%, ESBest=61.61%,
# Epoch 6: Loss= 0.7588, Accuracy: 57.14%, Max Acc: 0.00 TrueBest=61.61%, ESBest=61.61%,
# Epoch 7: Loss= 0.6962, Accuracy: 63.84%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.84%,
# Epoch 8: Loss= 0.6718, Accuracy: 64.29%, Max Acc: 0.00 TrueBest=64.29%, ESBest=63.84%,
# Epoch 9: Loss= 0.6841, Accuracy: 62.05%, Max Acc: 0.00 TrueBest=64.29%, ESBest=63.84%,
# Epoch 10: Loss= 0.5846, Accuracy: 64.29%, Max Acc: 0.00 TrueBest=64.29%, ESBest=63.84%,
# Epoch 11: Loss= 0.5792, Accuracy: 59.82%, Max Acc: 0.00 TrueBest=64.29%, ESBest=63.84%,
# Epoch 12: Loss= 0.5499, Accuracy: 60.71%, Max Acc: 0.00 TrueBest=64.29%, ESBest=63.84%,
# Epoch 13: Loss= 0.5035, Accuracy: 62.05%, Max Acc: 0.00 TrueBest=64.29%, ESBest=63.84%,
# Epoch 14: Loss= 0.4888, Accuracy: 63.39%, Max Acc: 0.00 TrueBest=64.29%, ESBest=63.84%,
# Stopping Early ....
# Epoch 0: Loss= 1.7397, Accuracy: 34.82%, Max Acc: 0.00 TrueBest=34.82%, ESBest=34.82%,
# Epoch 1: Loss= 1.3608, Accuracy: 48.66%, Max Acc: 0.00 TrueBest=48.66%, ESBest=48.66%,
# Epoch 2: Loss= 1.1010, Accuracy: 46.43%, Max Acc: 0.00 TrueBest=48.66%, ESBest=48.66%,
# Epoch 3: Loss= 1.0084, Accuracy: 54.02%, Max Acc: 0.00 TrueBest=54.02%, ESBest=54.02%,
# Epoch 4: Loss= 0.9294, Accuracy: 57.59%, Max Acc: 0.00 TrueBest=57.59%, ESBest=57.59%,
# Epoch 5: Loss= 0.8499, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 6: Loss= 0.7687, Accuracy: 56.70%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 7: Loss= 0.7150, Accuracy: 54.91%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 8: Loss= 0.7275, Accuracy: 55.36%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 9: Loss= 0.6593, Accuracy: 60.27%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 10: Loss= 0.6499, Accuracy: 58.48%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 11: Loss= 0.6152, Accuracy: 59.38%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 12: Loss= 0.5279, Accuracy: 59.38%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 13: Loss= 0.5378, Accuracy: 58.48%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 14: Loss= 0.4910, Accuracy: 61.16%, Max Acc: 0.00 TrueBest=61.16%, ESBest=61.16%,
# Epoch 0: Loss= 1.7844, Accuracy: 33.93%, Max Acc: 0.00 TrueBest=33.93%, ESBest=33.93%,
# Epoch 1: Loss= 1.4321, Accuracy: 44.20%, Max Acc: 0.00 TrueBest=44.20%, ESBest=44.20%,
# Epoch 2: Loss= 1.2241, Accuracy: 50.00%, Max Acc: 0.00 TrueBest=50.00%, ESBest=50.00%,
# Epoch 3: Loss= 1.0215, Accuracy: 53.57%, Max Acc: 0.00 TrueBest=53.57%, ESBest=53.57%,
# Epoch 4: Loss= 0.9660, Accuracy: 59.82%, Max Acc: 0.00 TrueBest=59.82%, ESBest=59.82%,
# Epoch 5: Loss= 0.8498, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.95%,
# Epoch 6: Loss= 0.7795, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.95%,
# Epoch 7: Loss= 0.7600, Accuracy: 66.07%, Max Acc: 0.00 TrueBest=66.07%, ESBest=66.07%,
# Epoch 8: Loss= 0.6847, Accuracy: 64.29%, Max Acc: 0.00 TrueBest=66.07%, ESBest=66.07%,
# Epoch 9: Loss= 0.6284, Accuracy: 63.84%, Max Acc: 0.00 TrueBest=66.07%, ESBest=66.07%,
# Epoch 10: Loss= 0.6053, Accuracy: 66.52%, Max Acc: 0.00 TrueBest=66.52%, ESBest=66.07%,
# Epoch 11: Loss= 0.5345, Accuracy: 66.96%, Max Acc: 0.00 TrueBest=66.96%, ESBest=66.96%,
# Epoch 12: Loss= 0.5136, Accuracy: 65.18%, Max Acc: 0.00 TrueBest=66.96%, ESBest=66.96%,
# Epoch 13: Loss= 0.5196, Accuracy: 66.52%, Max Acc: 0.00 TrueBest=66.96%, ESBest=66.96%,
# Epoch 14: Loss= 0.4749, Accuracy: 68.30%, Max Acc: 0.00 TrueBest=68.30%, ESBest=68.30%,
# Epoch 0: Loss= 1.7219, Accuracy: 36.61%, Max Acc: 0.00 TrueBest=36.61%, ESBest=36.61%,
# Epoch 1: Loss= 1.3288, Accuracy: 44.20%, Max Acc: 0.00 TrueBest=44.20%, ESBest=44.20%,
# Epoch 2: Loss= 1.1750, Accuracy: 49.11%, Max Acc: 0.00 TrueBest=49.11%, ESBest=49.11%,
# Epoch 3: Loss= 1.0196, Accuracy: 54.91%, Max Acc: 0.00 TrueBest=54.91%, ESBest=54.91%,
# Epoch 4: Loss= 0.8929, Accuracy: 53.57%, Max Acc: 0.00 TrueBest=54.91%, ESBest=54.91%,
# Epoch 5: Loss= 0.8477, Accuracy: 59.38%, Max Acc: 0.00 TrueBest=59.38%, ESBest=59.38%,
# Epoch 6: Loss= 0.7701, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=59.38%, ESBest=59.38%,
# Epoch 7: Loss= 0.6716, Accuracy: 66.07%, Max Acc: 0.00 TrueBest=66.07%, ESBest=66.07%,
# Epoch 8: Loss= 0.6538, Accuracy: 66.96%, Max Acc: 0.00 TrueBest=66.96%, ESBest=66.96%,
# Epoch 9: Loss= 0.6053, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=66.96%, ESBest=66.96%,
# Epoch 10: Loss= 0.5578, Accuracy: 64.29%, Max Acc: 0.00 TrueBest=66.96%, ESBest=66.96%,
# Epoch 11: Loss= 0.5641, Accuracy: 65.62%, Max Acc: 0.00 TrueBest=66.96%, ESBest=66.96%,
# Epoch 12: Loss= 0.5537, Accuracy: 65.18%, Max Acc: 0.00 TrueBest=66.96%, ESBest=66.96%,
# Epoch 13: Loss= 0.5008, Accuracy: 66.52%, Max Acc: 0.00 TrueBest=66.96%, ESBest=66.96%,
# Epoch 14: Loss= 0.4510, Accuracy: 65.62%, Max Acc: 0.00 TrueBest=66.96%, ESBest=66.96%,
# Epoch 0: Loss= 1.7271, Accuracy: 32.59%, Max Acc: 0.00 TrueBest=32.59%, ESBest=32.59%,
# Epoch 1: Loss= 1.3182, Accuracy: 44.64%, Max Acc: 0.00 TrueBest=44.64%, ESBest=44.64%,
# Epoch 2: Loss= 1.1326, Accuracy: 48.66%, Max Acc: 0.00 TrueBest=48.66%, ESBest=48.66%,
# Epoch 3: Loss= 1.0109, Accuracy: 55.36%, Max Acc: 0.00 TrueBest=55.36%, ESBest=55.36%,
# Epoch 4: Loss= 0.9359, Accuracy: 57.59%, Max Acc: 0.00 TrueBest=57.59%, ESBest=57.59%,
# Epoch 5: Loss= 0.8098, Accuracy: 59.82%, Max Acc: 0.00 TrueBest=59.82%, ESBest=59.82%,
# Epoch 6: Loss= 0.7861, Accuracy: 59.82%, Max Acc: 0.00 TrueBest=59.82%, ESBest=59.82%,
# Epoch 7: Loss= 0.7482, Accuracy: 62.50%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# Epoch 8: Loss= 0.6873, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# Epoch 9: Loss= 0.6374, Accuracy: 61.61%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# Epoch 10: Loss= 0.6049, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.50%,
# Epoch 11: Loss= 0.5487, Accuracy: 64.29%, Max Acc: 0.00 TrueBest=64.29%, ESBest=64.29%,
# Epoch 12: Loss= 0.5457, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=64.29%, ESBest=64.29%,
# Epoch 13: Loss= 0.5428, Accuracy: 60.71%, Max Acc: 0.00 TrueBest=64.29%, ESBest=64.29%,
# Epoch 14: Loss= 0.4828, Accuracy: 60.71%, Max Acc: 0.00 TrueBest=64.29%, ESBest=64.29%,
# Better hyperparameters found
# --------------
# Best accuracy for combo of learning rate and dropout = 0.6830357142857143
# Accuracies for the entire fold [0.6383928571428571, 0.6116071428571429, 0.6830357142857143, 0.6696428571428571, 0.6428571428571429]
# Mean accuracy for the fold 0.6491071428571429
# --------------
# Epoch 0: Loss= 1.7867, Accuracy: 32.14%, Max Acc: 0.00 TrueBest=32.14%, ESBest=32.14%,
# Epoch 1: Loss= 1.4249, Accuracy: 41.07%, Max Acc: 0.00 TrueBest=41.07%, ESBest=41.07%,
# Epoch 2: Loss= 1.1897, Accuracy: 49.55%, Max Acc: 0.00 TrueBest=49.55%, ESBest=49.55%,
# Epoch 3: Loss= 1.0184, Accuracy: 54.02%, Max Acc: 0.00 TrueBest=54.02%, ESBest=54.02%,
# Epoch 4: Loss= 0.9921, Accuracy: 55.80%, Max Acc: 0.00 TrueBest=55.80%, ESBest=55.80%,
# Epoch 5: Loss= 0.8246, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 6: Loss= 0.7749, Accuracy: 57.59%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 7: Loss= 0.7428, Accuracy: 62.50%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# Epoch 8: Loss= 0.7153, Accuracy: 59.38%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# Epoch 9: Loss= 0.6902, Accuracy: 60.27%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# Epoch 10: Loss= 0.6271, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.50%,
# Epoch 11: Loss= 0.5886, Accuracy: 63.39%, Max Acc: 0.00 TrueBest=63.39%, ESBest=63.39%,
# Epoch 12: Loss= 0.5790, Accuracy: 61.61%, Max Acc: 0.00 TrueBest=63.39%, ESBest=63.39%,
# Epoch 13: Loss= 0.5425, Accuracy: 61.61%, Max Acc: 0.00 TrueBest=63.39%, ESBest=63.39%,
# Epoch 14: Loss= 0.5347, Accuracy: 69.20%, Max Acc: 0.00 TrueBest=69.20%, ESBest=69.20%,
# Epoch 0: Loss= 1.7445, Accuracy: 33.48%, Max Acc: 0.00 TrueBest=33.48%, ESBest=33.48%,
# Epoch 1: Loss= 1.3752, Accuracy: 44.20%, Max Acc: 0.00 TrueBest=44.20%, ESBest=44.20%,
# Epoch 2: Loss= 1.1856, Accuracy: 49.11%, Max Acc: 0.00 TrueBest=49.11%, ESBest=49.11%,
# Epoch 3: Loss= 1.0172, Accuracy: 54.02%, Max Acc: 0.00 TrueBest=54.02%, ESBest=54.02%,
# Epoch 4: Loss= 0.9451, Accuracy: 57.59%, Max Acc: 0.00 TrueBest=57.59%, ESBest=57.59%,
# Epoch 5: Loss= 0.8808, Accuracy: 61.61%, Max Acc: 0.00 TrueBest=61.61%, ESBest=61.61%,
# Epoch 6: Loss= 0.8248, Accuracy: 61.16%, Max Acc: 0.00 TrueBest=61.61%, ESBest=61.61%,
# Epoch 7: Loss= 0.8052, Accuracy: 60.27%, Max Acc: 0.00 TrueBest=61.61%, ESBest=61.61%,
# Epoch 8: Loss= 0.7304, Accuracy: 57.59%, Max Acc: 0.00 TrueBest=61.61%, ESBest=61.61%,
# Epoch 9: Loss= 0.7133, Accuracy: 59.82%, Max Acc: 0.00 TrueBest=61.61%, ESBest=61.61%,
# Epoch 10: Loss= 0.6641, Accuracy: 61.16%, Max Acc: 0.00 TrueBest=61.61%, ESBest=61.61%,
# Epoch 11: Loss= 0.6675, Accuracy: 62.50%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# Epoch 12: Loss= 0.6212, Accuracy: 61.61%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# Epoch 13: Loss= 0.5791, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.50%,
# Epoch 14: Loss= 0.5804, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.50%,
# Epoch 0: Loss= 1.7774, Accuracy: 37.95%, Max Acc: 0.00 TrueBest=37.95%, ESBest=37.95%,
# Epoch 1: Loss= 1.3658, Accuracy: 49.55%, Max Acc: 0.00 TrueBest=49.55%, ESBest=49.55%,
# Epoch 2: Loss= 1.1631, Accuracy: 53.12%, Max Acc: 0.00 TrueBest=53.12%, ESBest=53.12%,
# Epoch 3: Loss= 1.0663, Accuracy: 58.04%, Max Acc: 0.00 TrueBest=58.04%, ESBest=58.04%,
# Epoch 4: Loss= 0.9602, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 5: Loss= 0.8745, Accuracy: 59.38%, Max Acc: 0.00 TrueBest=59.38%, ESBest=58.93%,
# Epoch 6: Loss= 0.8128, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.95%,
# Epoch 7: Loss= 0.7356, Accuracy: 64.73%, Max Acc: 0.00 TrueBest=64.73%, ESBest=64.73%,
# Epoch 8: Loss= 0.7212, Accuracy: 62.50%, Max Acc: 0.00 TrueBest=64.73%, ESBest=64.73%,
# Epoch 9: Loss= 0.6846, Accuracy: 61.61%, Max Acc: 0.00 TrueBest=64.73%, ESBest=64.73%,
# Epoch 10: Loss= 0.6740, Accuracy: 63.39%, Max Acc: 0.00 TrueBest=64.73%, ESBest=64.73%,
# Epoch 11: Loss= 0.6381, Accuracy: 61.16%, Max Acc: 0.00 TrueBest=64.73%, ESBest=64.73%,
# Epoch 12: Loss= 0.5915, Accuracy: 63.39%, Max Acc: 0.00 TrueBest=64.73%, ESBest=64.73%,
# Epoch 13: Loss= 0.5681, Accuracy: 60.71%, Max Acc: 0.00 TrueBest=64.73%, ESBest=64.73%,
# Epoch 14: Loss= 0.5789, Accuracy: 61.16%, Max Acc: 0.00 TrueBest=64.73%, ESBest=64.73%,
# Stopping Early ....
# Epoch 0: Loss= 1.7057, Accuracy: 41.52%, Max Acc: 0.00 TrueBest=41.52%, ESBest=41.52%,
# Epoch 1: Loss= 1.3356, Accuracy: 48.21%, Max Acc: 0.00 TrueBest=48.21%, ESBest=48.21%,
# Epoch 2: Loss= 1.0965, Accuracy: 49.11%, Max Acc: 0.00 TrueBest=49.11%, ESBest=49.11%,
# Epoch 3: Loss= 0.9822, Accuracy: 56.70%, Max Acc: 0.00 TrueBest=56.70%, ESBest=56.70%,
# Epoch 4: Loss= 0.9730, Accuracy: 55.80%, Max Acc: 0.00 TrueBest=56.70%, ESBest=56.70%,
# Epoch 5: Loss= 0.8600, Accuracy: 58.04%, Max Acc: 0.00 TrueBest=58.04%, ESBest=58.04%,
# Epoch 6: Loss= 0.8065, Accuracy: 60.27%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 7: Loss= 0.7821, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 8: Loss= 0.7467, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 9: Loss= 0.6844, Accuracy: 62.50%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# Epoch 10: Loss= 0.6791, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.50%,
# Epoch 11: Loss= 0.6822, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.50%,
# Epoch 12: Loss= 0.6330, Accuracy: 58.48%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.50%,
# Epoch 13: Loss= 0.5884, Accuracy: 63.39%, Max Acc: 0.00 TrueBest=63.39%, ESBest=63.39%,
# Epoch 14: Loss= 0.5751, Accuracy: 63.84%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.39%,
# Epoch 0: Loss= 1.7481, Accuracy: 37.50%, Max Acc: 0.00 TrueBest=37.50%, ESBest=37.50%,
# Epoch 1: Loss= 1.3310, Accuracy: 46.88%, Max Acc: 0.00 TrueBest=46.88%, ESBest=46.88%,
# Epoch 2: Loss= 1.1248, Accuracy: 50.89%, Max Acc: 0.00 TrueBest=50.89%, ESBest=50.89%,
# Epoch 3: Loss= 0.9992, Accuracy: 54.02%, Max Acc: 0.00 TrueBest=54.02%, ESBest=54.02%,
# Epoch 4: Loss= 0.9317, Accuracy: 55.80%, Max Acc: 0.00 TrueBest=55.80%, ESBest=55.80%,
# Epoch 5: Loss= 0.8877, Accuracy: 56.70%, Max Acc: 0.00 TrueBest=56.70%, ESBest=56.70%,
# Epoch 6: Loss= 0.8154, Accuracy: 58.48%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 7: Loss= 0.7538, Accuracy: 55.36%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 8: Loss= 0.7420, Accuracy: 60.27%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 9: Loss= 0.7090, Accuracy: 61.16%, Max Acc: 0.00 TrueBest=61.16%, ESBest=61.16%,
# Epoch 10: Loss= 0.6349, Accuracy: 61.16%, Max Acc: 0.00 TrueBest=61.16%, ESBest=61.16%,
# Epoch 11: Loss= 0.6303, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=61.16%, ESBest=61.16%,
# Epoch 12: Loss= 0.6022, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=61.16%, ESBest=61.16%,
# Epoch 13: Loss= 0.6008, Accuracy: 62.50%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# Epoch 14: Loss= 0.5947, Accuracy: 60.71%, Max Acc: 0.00 TrueBest=62.50%, ESBest=62.50%,
# --------------
# Best accuracy for combo of learning rate and dropout = 0.6919642857142857
# Accuracies for the entire fold [0.6919642857142857, 0.625, 0.6473214285714286, 0.6339285714285714, 0.625]
# Mean accuracy for the fold 0.6446428571428571
# --------------
# Epoch 0: Loss= 1.7625, Accuracy: 32.14%, Max Acc: 0.00 TrueBest=32.14%, ESBest=32.14%,
# Epoch 1: Loss= 1.3839, Accuracy: 41.96%, Max Acc: 0.00 TrueBest=41.96%, ESBest=41.96%,
# Epoch 2: Loss= 1.1901, Accuracy: 49.55%, Max Acc: 0.00 TrueBest=49.55%, ESBest=49.55%,
# Epoch 3: Loss= 1.0828, Accuracy: 48.21%, Max Acc: 0.00 TrueBest=49.55%, ESBest=49.55%,
# Epoch 4: Loss= 0.9978, Accuracy: 53.57%, Max Acc: 0.00 TrueBest=53.57%, ESBest=53.57%,
# Epoch 5: Loss= 0.9303, Accuracy: 54.91%, Max Acc: 0.00 TrueBest=54.91%, ESBest=54.91%,
# Epoch 6: Loss= 0.8928, Accuracy: 58.48%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 7: Loss= 0.8724, Accuracy: 53.57%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 8: Loss= 0.8235, Accuracy: 56.25%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 9: Loss= 0.8013, Accuracy: 57.59%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 10: Loss= 0.7210, Accuracy: 55.36%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 11: Loss= 0.7212, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.48%,
# Epoch 12: Loss= 0.6680, Accuracy: 58.04%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.48%,
# Epoch 13: Loss= 0.6364, Accuracy: 58.04%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.48%,
# Stopping Early ....
# Epoch 0: Loss= 1.8153, Accuracy: 29.91%, Max Acc: 0.00 TrueBest=29.91%, ESBest=29.91%,
# Epoch 1: Loss= 1.4917, Accuracy: 35.27%, Max Acc: 0.00 TrueBest=35.27%, ESBest=35.27%,
# Epoch 2: Loss= 1.2737, Accuracy: 39.29%, Max Acc: 0.00 TrueBest=39.29%, ESBest=39.29%,
# Epoch 3: Loss= 1.1959, Accuracy: 48.66%, Max Acc: 0.00 TrueBest=48.66%, ESBest=48.66%,
# Epoch 4: Loss= 1.0397, Accuracy: 45.54%, Max Acc: 0.00 TrueBest=48.66%, ESBest=48.66%,
# Epoch 5: Loss= 1.0081, Accuracy: 47.32%, Max Acc: 0.00 TrueBest=48.66%, ESBest=48.66%,
# Epoch 6: Loss= 0.9209, Accuracy: 53.12%, Max Acc: 0.00 TrueBest=53.12%, ESBest=53.12%,
# Epoch 7: Loss= 0.8375, Accuracy: 52.23%, Max Acc: 0.00 TrueBest=53.12%, ESBest=53.12%,
# Epoch 8: Loss= 0.8122, Accuracy: 53.12%, Max Acc: 0.00 TrueBest=53.12%, ESBest=53.12%,
# Epoch 9: Loss= 0.7628, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 10: Loss= 0.7646, Accuracy: 57.59%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 11: Loss= 0.6935, Accuracy: 60.27%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 12: Loss= 0.6619, Accuracy: 59.38%, Max Acc: 0.00 TrueBest=60.27%, ESBest=60.27%,
# Epoch 13: Loss= 0.6413, Accuracy: 63.84%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.84%,
# Epoch 14: Loss= 0.6361, Accuracy: 62.05%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.84%,
# Epoch 0: Loss= 1.7989, Accuracy: 31.70%, Max Acc: 0.00 TrueBest=31.70%, ESBest=31.70%,
# Epoch 1: Loss= 1.4715, Accuracy: 42.86%, Max Acc: 0.00 TrueBest=42.86%, ESBest=42.86%,
# Epoch 2: Loss= 1.2497, Accuracy: 46.88%, Max Acc: 0.00 TrueBest=46.88%, ESBest=46.88%,
# Epoch 3: Loss= 1.1293, Accuracy: 50.00%, Max Acc: 0.00 TrueBest=50.00%, ESBest=50.00%,
# Epoch 4: Loss= 1.0270, Accuracy: 58.48%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 5: Loss= 0.9397, Accuracy: 58.04%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 6: Loss= 0.8825, Accuracy: 58.48%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 7: Loss= 0.7939, Accuracy: 62.05%, Max Acc: 0.00 TrueBest=62.05%, ESBest=62.05%,
# Epoch 8: Loss= 0.7380, Accuracy: 63.84%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.84%,
# Epoch 9: Loss= 0.7197, Accuracy: 63.39%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.84%,
# Epoch 10: Loss= 0.6779, Accuracy: 60.71%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.84%,
# Epoch 11: Loss= 0.6743, Accuracy: 62.05%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.84%,
# Epoch 12: Loss= 0.6125, Accuracy: 60.71%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.84%,
# Epoch 13: Loss= 0.5824, Accuracy: 61.61%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.84%,
# Epoch 14: Loss= 0.5654, Accuracy: 60.27%, Max Acc: 0.00 TrueBest=63.84%, ESBest=63.84%,
# Epoch 0: Loss= 1.8016, Accuracy: 27.68%, Max Acc: 0.00 TrueBest=27.68%, ESBest=27.68%,
# Epoch 1: Loss= 1.4878, Accuracy: 44.64%, Max Acc: 0.00 TrueBest=44.64%, ESBest=44.64%,
# Epoch 2: Loss= 1.3097, Accuracy: 50.00%, Max Acc: 0.00 TrueBest=50.00%, ESBest=50.00%,
# Epoch 3: Loss= 1.2007, Accuracy: 55.36%, Max Acc: 0.00 TrueBest=55.36%, ESBest=55.36%,
# Epoch 4: Loss= 1.0474, Accuracy: 57.14%, Max Acc: 0.00 TrueBest=57.14%, ESBest=57.14%,
# Epoch 5: Loss= 1.0095, Accuracy: 58.48%, Max Acc: 0.00 TrueBest=58.48%, ESBest=58.48%,
# Epoch 6: Loss= 0.9076, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.48%,
# Epoch 7: Loss= 0.8288, Accuracy: 59.82%, Max Acc: 0.00 TrueBest=59.82%, ESBest=59.82%,
# Epoch 8: Loss= 0.8167, Accuracy: 60.71%, Max Acc: 0.00 TrueBest=60.71%, ESBest=60.71%,
# Epoch 9: Loss= 0.7429, Accuracy: 59.82%, Max Acc: 0.00 TrueBest=60.71%, ESBest=60.71%,
# Epoch 10: Loss= 0.7677, Accuracy: 62.95%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.95%,
# Epoch 11: Loss= 0.6538, Accuracy: 60.27%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.95%,
# Epoch 12: Loss= 0.6845, Accuracy: 61.16%, Max Acc: 0.00 TrueBest=62.95%, ESBest=62.95%,
# Epoch 13: Loss= 0.6387, Accuracy: 64.73%, Max Acc: 0.00 TrueBest=64.73%, ESBest=64.73%,
# Epoch 14: Loss= 0.6503, Accuracy: 59.38%, Max Acc: 0.00 TrueBest=64.73%, ESBest=64.73%,
# Epoch 0: Loss= 1.8146, Accuracy: 28.57%, Max Acc: 0.00 TrueBest=28.57%, ESBest=28.57%,
# Epoch 1: Loss= 1.4863, Accuracy: 36.61%, Max Acc: 0.00 TrueBest=36.61%, ESBest=36.61%,
# Epoch 2: Loss= 1.2958, Accuracy: 37.50%, Max Acc: 0.00 TrueBest=37.50%, ESBest=37.50%,
# Epoch 3: Loss= 1.1239, Accuracy: 46.88%, Max Acc: 0.00 TrueBest=46.88%, ESBest=46.88%,
# Epoch 4: Loss= 1.0380, Accuracy: 50.00%, Max Acc: 0.00 TrueBest=50.00%, ESBest=50.00%,
# Epoch 5: Loss= 0.9809, Accuracy: 52.68%, Max Acc: 0.00 TrueBest=52.68%, ESBest=52.68%,
# Epoch 6: Loss= 0.9104, Accuracy: 53.57%, Max Acc: 0.00 TrueBest=53.57%, ESBest=53.57%,
# Epoch 7: Loss= 0.8278, Accuracy: 57.59%, Max Acc: 0.00 TrueBest=57.59%, ESBest=57.59%,
# Epoch 8: Loss= 0.8411, Accuracy: 51.34%, Max Acc: 0.00 TrueBest=57.59%, ESBest=57.59%,
# Epoch 9: Loss= 0.7921, Accuracy: 54.46%, Max Acc: 0.00 TrueBest=57.59%, ESBest=57.59%,
# Epoch 10: Loss= 0.7690, Accuracy: 55.36%, Max Acc: 0.00 TrueBest=57.59%, ESBest=57.59%,
# Epoch 11: Loss= 0.7183, Accuracy: 53.12%, Max Acc: 0.00 TrueBest=57.59%, ESBest=57.59%,
# Epoch 12: Loss= 0.6798, Accuracy: 58.93%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 13: Loss= 0.6574, Accuracy: 57.59%, Max Acc: 0.00 TrueBest=58.93%, ESBest=58.93%,
# Epoch 14: Loss= 0.6482, Accuracy: 59.82%, Max Acc: 0.00 TrueBest=59.82%, ESBest=59.82%,
# --------------
# Best accuracy for combo of learning rate and dropout = 0.6473214285714286
# Accuracies for the entire fold [0.5848214285714286, 0.6383928571428571, 0.6383928571428571, 0.6473214285714286, 0.5982142857142857]
# Mean accuracy for the fold 0.6214285714285713
# --------------

# %%
print(f"best_dropout = {best_dropout } "
        f"best_lr = {best_lr} "
        f"max_accuracy = {max_accuracy} ")
# Out:
# best_dropout = 0.1 best_lr = 0.001 max_accuracy = 0.6491071428571429

# %% [markdown]
# # Training a new model using the hyperparameters

# %%
best_dropout = 0.1
best_lr = 0.001

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1120, 1, 24, 1500)
# (1120,)

# %%
train_ds = BCIDataset(X_train, y_train)
val_ds = BCIDataset(X_test, y_test)

train_final_loader = DataLoader(train_ds, batch_size=16, shuffle=True)
val_final_loader = DataLoader(val_ds, batch_size=16, shuffle=False)

model_final = EEGNet(num_classes= 7, num_channels=24, input_samples=1500, dropout_rate=best_dropout)
model_final = model_final.to(device)
optimizer = optim.Adam(model_final.parameters(), lr=best_lr)
criterion = nn.CrossEntropyLoss()


mx_acc = 0
for epoch in range(12):
    loss = train(model_final, train_final_loader, criterion, optimizer, device)
    acc = evaluate(model_final, val_final_loader, device)
    if acc > mx_acc:
        mx_acc = acc
    print(f"Epoch {epoch}: Loss= {loss:.4f}, Accuracy: {acc*100:.2f}%, Max Acc: {mx_acc*100:.2f}")
# Out:
# Epoch 0: Loss= 1.7081, Accuracy: 42.50%, Max Acc: 42.50
# Epoch 1: Loss= 1.1779, Accuracy: 46.43%, Max Acc: 46.43
# Epoch 2: Loss= 0.9522, Accuracy: 61.43%, Max Acc: 61.43
# Epoch 3: Loss= 0.8267, Accuracy: 62.14%, Max Acc: 62.14
# Epoch 4: Loss= 0.7504, Accuracy: 62.50%, Max Acc: 62.50
# Epoch 5: Loss= 0.6570, Accuracy: 65.71%, Max Acc: 65.71
# Epoch 6: Loss= 0.5936, Accuracy: 72.86%, Max Acc: 72.86
# Epoch 7: Loss= 0.5440, Accuracy: 63.57%, Max Acc: 72.86
# Epoch 8: Loss= 0.5170, Accuracy: 66.07%, Max Acc: 72.86
# Epoch 9: Loss= 0.4729, Accuracy: 67.50%, Max Acc: 72.86
# Epoch 10: Loss= 0.4333, Accuracy: 73.21%, Max Acc: 73.21
# Epoch 11: Loss= 0.4223, Accuracy: 68.93%, Max Acc: 73.21

# %% [markdown]
# # Evaluation phase

# %%
acc = evaluateFinal(model_final, train_final_loader, device)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6.], dtype=float32), array([163, 157, 162, 214, 195,  74, 155]))
# The accuracy for the test is 88.12%

# %%
acc = evaluateFinal(model_final, val_final_loader, device)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6.], dtype=float32), array([38, 33, 41, 76, 53,  7, 32]))
# The accuracy for the test is 68.93%
