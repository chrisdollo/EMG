# %% [markdown]
# # Feature Extraction Driver
#
# Two modes:
# - **Single file** — `extract_features(input_filepath, output_filepath, ...)`
# - **Batch (folder)** — `batch_extract_features(input_dir, output_dir, ...)` processes every `.mat` file in `input_dir` (no recursion). Existing outputs are always deleted and re-created.

# %%
from feature_extraction import batch_extract_features

batch_extract_features(
    input_dir     = "/Users/chrisdollo/Documents/Research/putEMG prime/Data/X/gesture_per_subject_data_5",
    output_dir    = "/Users/chrisdollo/Documents/Research/putEMG prime/Data/X/feature_files",
    window_size   = 250,
    window_shift  = 50,
    sampling_rate = 5120.0,
)
# Out:
# Found 5 .mat file(s) in:
#   /Users/chrisdollo/Documents/Research/putEMG prime/Data/X/gesture_per_subject_data_5
#
# ─── emg_gestures_03_combined_non_uniform.mat  →  features_subject_03.mat
# Loaded  : emg_gestures_03_combined_non_uniform.mat
# Shape   : 40 repetitions × 7 gestures
# Window  : size=250, shift=50, fs=5120.0 Hz
# Features: 8 per channel × 24 channels = 192 total
#
#   Gesture G1 (class 0) — accumulated 8020 windows so far
#   Gesture G2 (class 1) — accumulated 16040 windows so far
#   Gesture G3 (class 2) — accumulated 24060 windows so far
#   Gesture G6 (class 3) — accumulated 32080 windows so far
#   Gesture G7 (class 4) — accumulated 40100 windows so far
#   Gesture G8 (class 5) — accumulated 48120 windows so far
#   Gesture G9 (class 6) — accumulated 56140 windows so far
#
# Feature matrix : X=(56140, 192), y=(56140,)
# Class distribution: {'G1': 8020, 'G2': 8020, 'G3': 8020, 'G6': 8020, 'G7': 8020, 'G8': 8020, 'G9': 8020}
#
# ...
