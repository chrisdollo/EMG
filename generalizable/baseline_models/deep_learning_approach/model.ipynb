# %% [markdown]
# # putEMG — Deep Learning Model Training & Evaluation
#
# Trains and evaluates CNN architectures on the putEMG gesture dataset using
# **Leave-One-Subject-Out (LOSO)** cross-validation.
#
# | # | Model | Description |
# |---|-------|-------------|
# | 1 | **EEGNet** | Depthwise separable CNN, original baseline |
# | 2 | **ShallowConvNet** | Temporal + spatial conv, square/log nonlinearity |
# | 3 | **DeepConvNet** | 4 stacked conv blocks, increasing filter depth |
# | 4 | **CNN_LSTM** | Spatial CNN → temporal pooling → 2-layer LSTM |
# | 5 | **EMG_TCN** | Spatial mixing + 4 dilated temporal conv blocks |
#
# **LOSO split (per fold):**
# - **Test** — 1 held-out subject (never seen during training)
# - **Val** — 10% of the remaining 43 subjects' data, stratified by class (early stopping only)
# - **Train** — remaining 90% of those 43 subjects
#
# Checkpointing lets you stop and resume at any time — completed folds are skipped automatically.
#
# > **Prerequisites**: Run `preprocessing_driver.ipynb` first to generate per-subject `.mat` files.

# %%
import os
import sys
import numpy as np
import datetime
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
# -- Shared utilities (public/) --
sys.path.append(os.path.abspath("../../../"))

import public.deep_learning_models as dlm
from public.emg_loader import load_all_subjects, make_loso_train_val_test

# %%
# ── Training & evaluation utilities ──────────────────────────────────────────
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def train(model, train_loader, criterion, optimizer, device):
    """One full epoch over train_loader. Returns mean batch loss."""
    model.train()   # enables dropout and batch-norm update
    total_loss = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()           # clear gradients from the previous batch
        out  = model(X)
        loss = criterion(out, y)        # cross-entropy between logits and true labels
        loss.backward()                 # backprop: compute gradients for all parameters
        optimizer.step()               # update weights using the computed gradients
        total_loss += loss.item()
    return total_loss / len(train_loader)   # mean loss across all batches


def evaluate(model, loader, device):
    """Returns top-1 accuracy over loader. No gradient computation."""
    model.eval()    # disables dropout, freezes batch-norm stats
    correct, total = 0, 0
    with torch.no_grad():
        for X, y in loader:
            X, y = X.to(device), y.to(device)
            pred = model(X).argmax(dim=1)   # predicted class = index of highest logit
            correct += (pred == y).sum().item()
            total   += y.size(0)
    return correct / total


def evaluateFinal(model, test_loader, device, plot=True):
    """Full evaluation with optional confusion matrix — use for post-hoc analysis."""
    model.eval()
    correct, total = 0, 0
    actual    = torch.tensor([], dtype=torch.int64)
    predicted = torch.tensor([], dtype=torch.int64)
    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to(device), y.to(device)
            pred = model(X).argmax(dim=1)
            correct   += (pred == y).sum().item()
            total     += y.size(0)
            # Accumulate all labels on CPU to build the confusion matrix after the loop
            actual    = torch.cat((actual,    y.cpu()),    dim=0)
            predicted = torch.cat((predicted, pred.cpu()), dim=0)

    acc = correct / total
    if plot:
        print(np.unique(predicted.numpy(), return_counts=True))
        cm = confusion_matrix(actual.numpy(), predicted.numpy())
        ConfusionMatrixDisplay(cm).plot()
    print(f'Test accuracy: {acc * 100:.2f}%')
    return acc

# %%
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: mps

# %%
_notebook_dir = os.path.abspath(os.getcwd())

# %%
# -- Paths --
DATA_DIR    = '/Volumes/KRIS/data/UG_per_subject'
WEIGHTS_DIR = os.path.join(_notebook_dir, 'weights')
LOG_PATH    = os.path.join(_notebook_dir, 'results_log.txt')

# -- Data split --
BATCH_SIZE = 16
VAL_FRAC   = 0.10     # fraction of training pool held out for early stopping (stratified)

# -- Training --
MAX_EPOCHS = 20
PATIENCE   = 5
MIN_DELTA  = 0.002
LR         = 1e-3
DROPOUT    = 0.1

os.makedirs(WEIGHTS_DIR, exist_ok=True)
subjects = load_all_subjects(DATA_DIR)
print(f'\nWeights → {WEIGHTS_DIR}')
print(f'Log     → {LOG_PATH}')
# Out:
# Loading 44 subject file(s) from: /Volumes/KRIS/data/UG_per_subject
#
#   → emg_gestures_03_U.mat  (280 samples)
#   → emg_gestures_04_U.mat  (280 samples)
#   → emg_gestures_05_U.mat  (280 samples)
#   → emg_gestures_06_U.mat  (280 samples)
#   → emg_gestures_07_U.mat  (280 samples)
#   → emg_gestures_08_U.mat  (280 samples)
#   → emg_gestures_09_U.mat  (280 samples)
#   → emg_gestures_10_U.mat  (280 samples)
#   → emg_gestures_11_U.mat  (280 samples)
#   → emg_gestures_12_U.mat  (280 samples)
#   → emg_gestures_13_U.mat  (280 samples)
#   → emg_gestures_14_U.mat  (280 samples)
#   → emg_gestures_15_U.mat  (280 samples)
#   → emg_gestures_16_U.mat  (280 samples)
#   → emg_gestures_17_U.mat  (280 samples)
#   → emg_gestures_18_U.mat  (280 samples)
#   → emg_gestures_19_U.mat  (280 samples)
#   → emg_gestures_20_U.mat  (280 samples)
#   → emg_gestures_22_U.mat  (280 samples)
#   → emg_gestures_23_U.mat  (280 samples)
#   → emg_gestures_24_U.mat  (280 samples)
#   → emg_gestures_25_U.mat  (280 samples)
#   → emg_gestures_26_U.mat  (280 samples)
#   → emg_gestures_27_U.mat  (280 samples)
#   → emg_gestures_29_U.mat  (280 samples)
#   → emg_gestures_30_U.mat  (280 samples)
#   → emg_gestures_31_U.mat  (280 samples)
#   → emg_gestures_33_U.mat  (280 samples)
#   → emg_gestures_34_U.mat  (280 samples)
#   → emg_gestures_35_U.mat  (280 samples)
#   → emg_gestures_36_U.mat  (280 samples)
#   → emg_gestures_38_U.mat  (280 samples)
#   → emg_gestures_39_U.mat  (280 samples)
#   → emg_gestures_42_U.mat  (280 samples)
#   → emg_gestures_43_U.mat  (280 samples)
#   → emg_gestures_45_U.mat  (280 samples)
#   → emg_gestures_46_U.mat  (280 samples)
#   → emg_gestures_47_U.mat  (280 samples)
#   → emg_gestures_48_U.mat  (280 samples)
#   → emg_gestures_49_U.mat  (280 samples)
#   → emg_gestures_50_U.mat  (280 samples)
#   → emg_gestures_51_U.mat  (280 samples)
#   → emg_gestures_53_U.mat  (280 samples)
#   → emg_gestures_54_U.mat  (280 samples)
#
# Total subjects loaded: 44
#
# Weights → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/weights
# Log     → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt

# %% [markdown]
# ---
# ## LOSO Training Loop
#
# Trains **EMG_TCN** on every subject as a test fold:
#
# - **Test** — 1 held-out subject, never seen during training
# - **Train / Val** — all other 43 subjects, split 90/10 (stratified by class, seeded) within the pool
#
# Checkpointing:
# - Weights saved to `weights/EMG_TCN_<subject_id>.pt` after each fold
# - If a checkpoint already exists the fold is skipped — safe to stop and resume at any time
# - `results_log.txt` is rebuilt from all checkpoints after every fold

# %%
# ── Helpers ───────────────────────────────────────────────────────────────────

def subject_id(filename):
    """'emg_gestures_03_U.mat' → '03'"""
    return filename.replace('emg_gestures_', '').replace('_U.mat', '')


def weight_path(subject_name):
    return os.path.join(WEIGHTS_DIR, f'EMG_TCN_{subject_id(subject_name)}.pt')


def update_log():
    """Rebuild results_log.txt from all valid LOSO checkpoint files in WEIGHTS_DIR.
    
    Called after every completed fold so the log always reflects current progress.
    Skips any .pt files that lack a 'subject' key (old checkpoint format).
    """
    # Scan the weights folder and collect every valid checkpoint dict
    checkpoints = []
    for fname in sorted(os.listdir(WEIGHTS_DIR)):
        if not fname.endswith('.pt'):
            continue
        # Load weights to CPU regardless of where they were saved (MPS / CUDA / CPU)
        ckpt = torch.load(os.path.join(WEIGHTS_DIR, fname), map_location='cpu', weights_only=False)
        if 'subject' not in ckpt:   # skip old-format checkpoints that lack metadata
            continue
        checkpoints.append(ckpt)

    if not checkpoints:
        return

    # Extract per-fold accuracies for the summary statistics at the bottom
    accs    = [c['test_acc'] * 100 for c in checkpoints]
    n_done  = len(checkpoints)
    n_total = len(subjects)

    # Build the log line-by-line: header, one row per fold, then the aggregate summary
    lines = [
        'putEMG — EMG_TCN LOSO Results',
        '=' * 68,
        f"{'Subject':<28} {'Test Acc':>9}  {'Val Acc':>9}  {'Epoch':>6}  {'Date'}",
        '-' * 68,
    ]
    for c in checkpoints:
        lines.append(
            f"{c['subject']:<28} {c['test_acc']*100:>8.2f}%  "
            f"{c['val_acc']*100:>8.2f}%  {c['best_epoch']:>6}  {c['date']}"
        )
    lines += [
        '=' * 68,
        # Mean ± std across all completed folds; updates incrementally as folds finish
        f"Mean: {np.mean(accs):.2f}%  ±  {np.std(accs):.2f}%  "
        f"({n_done} / {n_total} folds complete)",
    ]

    with open(LOG_PATH, 'w') as f:
        f.write('\n'.join(lines) + '\n')

    print(f"Log updated → {LOG_PATH}  ({n_done}/{n_total} folds)")

# %%
# ── LOSO outer loop: iterate over every subject as the held-out test fold ─────
# Each iteration trains a fresh model on all OTHER subjects and tests on this one.
# Checkpointing: if a .pt file already exists for a subject, skip that fold —
# this makes it safe to interrupt and resume without re-training completed folds.
for test_idx, (test_name, _, _) in enumerate(subjects):
    wpath = weight_path(test_name)

    # Resume support: skip folds that already have a saved checkpoint
    if os.path.exists(wpath):
        print(f"[SKIP] {test_name}  — checkpoint found")
        continue

    print(f"\n{'='*60}")
    print(f"  Fold {test_idx+1}/{len(subjects)}  —  test: {test_name}")
    print(f"{'='*60}")

    # Build dataloaders for this fold:
    #   - test_loader  : only the held-out subject (never used during training)
    #   - train_loader : 90% of the remaining 43 subjects (stratified split)
    #   - val_loader   : the other 10%, used only for early stopping
    train_loader, val_loader, test_loader = make_loso_train_val_test(
        subjects, test_idx, val_frac=VAL_FRAC, batch_size=BATCH_SIZE
    )

    # Fresh model + optimizer for every fold — no weight leakage between subjects
    model     = dlm.EMG_TCN(dropout_rate=DROPOUT).to(device)
    optimizer = optim.Adam(model.parameters(), lr=LR)
    # Halve LR when val accuracy plateaus; protects against overshooting the optimum
    scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5, min_lr=1e-6)
    criterion = nn.CrossEntropyLoss()

    # Track the best validation checkpoint for early stopping
    best_val_acc = float('-inf')
    best_state   = None   # deep-copy of model weights at the best val epoch
    best_epoch   = 0
    bad_epochs   = 0      # consecutive epochs without a MIN_DELTA improvement

    # ── Inner loop: train for up to MAX_EPOCHS, stop early if val stagnates ──
    for epoch in range(MAX_EPOCHS):
        # One full pass over the training set; returns mean cross-entropy loss
        tr_loss = train(model, train_loader, criterion, optimizer, device)
        # Evaluate on the validation set (no gradients, no label leakage from test)
        val_acc = evaluate(model, val_loader, device)
        curr_lr = optimizer.param_groups[0]['lr']

        # Snapshot the weights whenever this epoch beats the previous best val accuracy
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            # Clone to CPU so GPU/MPS memory isn't held while training continues
            best_state   = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            best_epoch   = epoch + 1

        # Update LR scheduler with current val accuracy (mode='max')
        scheduler.step(val_acc)
        # Increment the stagnation counter; reset it if we're still within MIN_DELTA of the best
        bad_epochs = 0 if val_acc >= (best_val_acc - MIN_DELTA) else bad_epochs + 1

        print(f"  Epoch {epoch+1:3d}: loss={tr_loss:.4f}  val={val_acc*100:.2f}%  "
              f"best={best_val_acc*100:.2f}%  lr={curr_lr:.2e}")

        # Stop early if validation hasn't improved for PATIENCE consecutive epochs
        if bad_epochs >= PATIENCE:
            print(f"  Early stopping at epoch {epoch+1}.")
            break

    # Restore the best-seen weights before evaluating on the held-out test subject
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"\n  Test accuracy: {test_acc*100:.2f}%")

    # Save checkpoint with metadata so update_log() can rebuild the results file
    torch.save({
        'subject':    test_name,
        'test_acc':   test_acc,
        'val_acc':    best_val_acc,
        'best_epoch': best_epoch,
        'dropout':    DROPOUT,
        'state_dict': best_state,
        'date':       datetime.date.today().isoformat(),
    }, wpath)

    # Rebuild the log after every fold so progress is visible without waiting for completion
    update_log()

print(f"\n{'='*60}")
print("  All folds complete.")
print(f"{'='*60}")
update_log()
# Out:
# [SKIP] emg_gestures_03_U.mat  — checkpoint found
# [SKIP] emg_gestures_04_U.mat  — checkpoint found
# [SKIP] emg_gestures_05_U.mat  — checkpoint found
# [SKIP] emg_gestures_06_U.mat  — checkpoint found
# [SKIP] emg_gestures_07_U.mat  — checkpoint found
# [SKIP] emg_gestures_08_U.mat  — checkpoint found
# [SKIP] emg_gestures_09_U.mat  — checkpoint found
# [SKIP] emg_gestures_10_U.mat  — checkpoint found
# [SKIP] emg_gestures_11_U.mat  — checkpoint found
# [SKIP] emg_gestures_12_U.mat  — checkpoint found
# [SKIP] emg_gestures_13_U.mat  — checkpoint found
# [SKIP] emg_gestures_14_U.mat  — checkpoint found
# [SKIP] emg_gestures_15_U.mat  — checkpoint found
#
# ============================================================
#   Fold 14/44  —  test: emg_gestures_16_U.mat
# ============================================================
#   Test  : emg_gestures_16_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8459  val=77.99%  best=77.99%  lr=1.00e-03
#   Epoch   2: loss=0.5457  val=82.23%  best=82.23%  lr=1.00e-03
#   Epoch   3: loss=0.4520  val=82.48%  best=82.48%  lr=1.00e-03
#   Epoch   4: loss=0.3903  val=86.79%  best=86.79%  lr=1.00e-03
#   Epoch   5: loss=0.3490  val=86.46%  best=86.79%  lr=1.00e-03
#   Epoch   6: loss=0.3143  val=90.45%  best=90.45%  lr=1.00e-03
#   Epoch   7: loss=0.3068  val=90.28%  best=90.45%  lr=1.00e-03
#   Epoch   8: loss=0.2797  val=92.36%  best=92.36%  lr=1.00e-03
#   Epoch   9: loss=0.2620  val=89.53%  best=92.36%  lr=1.00e-03
#   Epoch  10: loss=0.2596  val=91.94%  best=92.36%  lr=1.00e-03
#   Epoch  11: loss=0.2397  val=92.61%  best=92.61%  lr=1.00e-03
#   Epoch  12: loss=0.2262  val=92.94%  best=92.94%  lr=1.00e-03
#   Epoch  13: loss=0.2132  val=92.52%  best=92.94%  lr=1.00e-03
#   Epoch  14: loss=0.2139  val=91.53%  best=92.94%  lr=1.00e-03
#   Epoch  15: loss=0.2052  val=93.60%  best=93.60%  lr=1.00e-03
#   Epoch  16: loss=0.1846  val=92.94%  best=93.60%  lr=1.00e-03
#   Epoch  17: loss=0.1870  val=92.94%  best=93.60%  lr=1.00e-03
#   Epoch  18: loss=0.1836  val=94.10%  best=94.10%  lr=1.00e-03
#   Epoch  19: loss=0.1695  val=93.69%  best=94.10%  lr=1.00e-03
#   Epoch  20: loss=0.1695  val=92.19%  best=94.10%  lr=1.00e-03
#
#   Test accuracy: 62.50%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (14/44 folds)
#
# ============================================================
#   Fold 15/44  —  test: emg_gestures_17_U.mat
# ============================================================
#   Test  : emg_gestures_17_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8682  val=79.32%  best=79.32%  lr=1.00e-03
#   Epoch   2: loss=0.5633  val=79.32%  best=79.32%  lr=1.00e-03
#   Epoch   3: loss=0.4675  val=86.71%  best=86.71%  lr=1.00e-03
#   Epoch   4: loss=0.4011  val=86.96%  best=86.96%  lr=1.00e-03
#   Epoch   5: loss=0.3692  val=88.21%  best=88.21%  lr=1.00e-03
#   Epoch   6: loss=0.3335  val=91.03%  best=91.03%  lr=1.00e-03
#   Epoch   7: loss=0.3104  val=89.78%  best=91.03%  lr=1.00e-03
#   Epoch   8: loss=0.2785  val=91.61%  best=91.61%  lr=1.00e-03
#   Epoch   9: loss=0.2659  val=90.28%  best=91.61%  lr=1.00e-03
#   Epoch  10: loss=0.2511  val=87.46%  best=91.61%  lr=1.00e-03
#   Epoch  11: loss=0.2475  val=90.86%  best=91.61%  lr=1.00e-03
#   Epoch  12: loss=0.2286  val=92.28%  best=92.28%  lr=1.00e-03
#   Epoch  13: loss=0.2281  val=92.61%  best=92.61%  lr=1.00e-03
#   Epoch  14: loss=0.2152  val=92.03%  best=92.61%  lr=1.00e-03
#   Epoch  15: loss=0.1985  val=93.85%  best=93.85%  lr=1.00e-03
#   Epoch  16: loss=0.1904  val=92.11%  best=93.85%  lr=1.00e-03
#   Epoch  17: loss=0.1950  val=93.52%  best=93.85%  lr=1.00e-03
#   Epoch  18: loss=0.1826  val=92.44%  best=93.85%  lr=1.00e-03
#   Epoch  19: loss=0.1757  val=91.36%  best=93.85%  lr=1.00e-03
#   Epoch  20: loss=0.1724  val=93.94%  best=93.94%  lr=1.00e-03
#
#   Test accuracy: 65.36%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (15/44 folds)
#
# ============================================================
#   Fold 16/44  —  test: emg_gestures_18_U.mat
# ============================================================
#   Test  : emg_gestures_18_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8580  val=76.41%  best=76.41%  lr=1.00e-03
#   Epoch   2: loss=0.5614  val=84.63%  best=84.63%  lr=1.00e-03
#   Epoch   3: loss=0.4388  val=85.80%  best=85.80%  lr=1.00e-03
#   Epoch   4: loss=0.3935  val=81.48%  best=85.80%  lr=1.00e-03
#   Epoch   5: loss=0.3529  val=91.03%  best=91.03%  lr=1.00e-03
#   Epoch   6: loss=0.3222  val=88.95%  best=91.03%  lr=1.00e-03
#   Epoch   7: loss=0.2931  val=90.70%  best=91.03%  lr=1.00e-03
#   Epoch   8: loss=0.2780  val=89.95%  best=91.03%  lr=1.00e-03
#   Epoch   9: loss=0.2565  val=90.70%  best=91.03%  lr=1.00e-03
#   Epoch  10: loss=0.2460  val=90.78%  best=91.03%  lr=1.00e-03
#   Early stopping at epoch 10.
#
#   Test accuracy: 71.07%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (16/44 folds)
#
# ============================================================
#   Fold 17/44  —  test: emg_gestures_19_U.mat
# ============================================================
#   Test  : emg_gestures_19_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8824  val=77.57%  best=77.57%  lr=1.00e-03
#   Epoch   2: loss=0.5724  val=84.97%  best=84.97%  lr=1.00e-03
#   Epoch   3: loss=0.4561  val=86.46%  best=86.46%  lr=1.00e-03
#   Epoch   4: loss=0.3947  val=86.46%  best=86.46%  lr=1.00e-03
#   Epoch   5: loss=0.3534  val=87.71%  best=87.71%  lr=1.00e-03
#   Epoch   6: loss=0.3081  val=90.20%  best=90.20%  lr=1.00e-03
#   Epoch   7: loss=0.2925  val=89.78%  best=90.20%  lr=1.00e-03
#   Epoch   8: loss=0.2750  val=93.44%  best=93.44%  lr=1.00e-03
#   Epoch   9: loss=0.2612  val=90.37%  best=93.44%  lr=1.00e-03
#   Epoch  10: loss=0.2402  val=92.86%  best=93.44%  lr=1.00e-03
#   Epoch  11: loss=0.2347  val=92.86%  best=93.44%  lr=1.00e-03
#   Epoch  12: loss=0.2293  val=92.61%  best=93.44%  lr=1.00e-03
#   Epoch  13: loss=0.2154  val=91.61%  best=93.44%  lr=1.00e-03
#   Early stopping at epoch 13.
#
#   Test accuracy: 70.36%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (17/44 folds)
#
# ============================================================
#   Fold 18/44  —  test: emg_gestures_20_U.mat
# ============================================================
#   Test  : emg_gestures_20_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8673  val=76.74%  best=76.74%  lr=1.00e-03
#   Epoch   2: loss=0.5803  val=80.32%  best=80.32%  lr=1.00e-03
#   Epoch   3: loss=0.4728  val=84.88%  best=84.88%  lr=1.00e-03
#   Epoch   4: loss=0.3980  val=87.87%  best=87.87%  lr=1.00e-03
#   Epoch   5: loss=0.3684  val=87.79%  best=87.87%  lr=1.00e-03
#   Epoch   6: loss=0.3357  val=89.20%  best=89.20%  lr=1.00e-03
#   Epoch   7: loss=0.3020  val=85.47%  best=89.20%  lr=1.00e-03
#   Epoch   8: loss=0.2884  val=91.69%  best=91.69%  lr=1.00e-03
#   Epoch   9: loss=0.2637  val=90.03%  best=91.69%  lr=1.00e-03
#   Epoch  10: loss=0.2564  val=92.36%  best=92.36%  lr=1.00e-03
#   Epoch  11: loss=0.2453  val=88.21%  best=92.36%  lr=1.00e-03
#   Epoch  12: loss=0.2280  val=91.28%  best=92.36%  lr=1.00e-03
#   Epoch  13: loss=0.2310  val=93.44%  best=93.44%  lr=1.00e-03
#   Epoch  14: loss=0.2182  val=92.69%  best=93.44%  lr=1.00e-03
#   Epoch  15: loss=0.2045  val=93.27%  best=93.44%  lr=1.00e-03
#   Epoch  16: loss=0.2061  val=91.86%  best=93.44%  lr=1.00e-03
#   Epoch  17: loss=0.1941  val=92.36%  best=93.44%  lr=1.00e-03
#   Epoch  18: loss=0.1797  val=94.19%  best=94.19%  lr=1.00e-03
#   Epoch  19: loss=0.1754  val=93.02%  best=94.19%  lr=1.00e-03
#   Epoch  20: loss=0.1711  val=89.78%  best=94.19%  lr=1.00e-03
#
#   Test accuracy: 76.79%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (18/44 folds)
#
# ============================================================
#   Fold 19/44  —  test: emg_gestures_22_U.mat
# ============================================================
#   Test  : emg_gestures_22_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8528  val=71.18%  best=71.18%  lr=1.00e-03
#   Epoch   2: loss=0.5830  val=83.72%  best=83.72%  lr=1.00e-03
#   Epoch   3: loss=0.4807  val=84.55%  best=84.55%  lr=1.00e-03
#   Epoch   4: loss=0.4094  val=86.46%  best=86.46%  lr=1.00e-03
#   Epoch   5: loss=0.3672  val=83.31%  best=86.46%  lr=1.00e-03
#   Epoch   6: loss=0.3330  val=85.05%  best=86.46%  lr=1.00e-03
#   Epoch   7: loss=0.3078  val=88.37%  best=88.37%  lr=1.00e-03
#   Epoch   8: loss=0.2861  val=92.03%  best=92.03%  lr=1.00e-03
#   Epoch   9: loss=0.2696  val=90.20%  best=92.03%  lr=1.00e-03
#   Epoch  10: loss=0.2481  val=88.95%  best=92.03%  lr=1.00e-03
#   Epoch  11: loss=0.2416  val=91.53%  best=92.03%  lr=1.00e-03
#   Epoch  12: loss=0.2417  val=89.20%  best=92.03%  lr=1.00e-03
#   Epoch  13: loss=0.2187  val=90.45%  best=92.03%  lr=1.00e-03
#   Early stopping at epoch 13.
#
#   Test accuracy: 78.21%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (19/44 folds)
#
# ============================================================
#   Fold 20/44  —  test: emg_gestures_23_U.mat
# ============================================================
#   Test  : emg_gestures_23_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8213  val=80.07%  best=80.07%  lr=1.00e-03
#   Epoch   2: loss=0.5340  val=86.21%  best=86.21%  lr=1.00e-03
#   Epoch   3: loss=0.4503  val=84.88%  best=86.21%  lr=1.00e-03
#   Epoch   4: loss=0.3886  val=87.29%  best=87.29%  lr=1.00e-03
#   Epoch   5: loss=0.3655  val=81.98%  best=87.29%  lr=1.00e-03
#   Epoch   6: loss=0.3282  val=89.12%  best=89.12%  lr=1.00e-03
#   Epoch   7: loss=0.3089  val=90.45%  best=90.45%  lr=1.00e-03
#   Epoch   8: loss=0.2838  val=89.95%  best=90.45%  lr=1.00e-03
#   Epoch   9: loss=0.2704  val=90.61%  best=90.61%  lr=1.00e-03
#   Epoch  10: loss=0.2567  val=90.12%  best=90.61%  lr=1.00e-03
#   Epoch  11: loss=0.2350  val=91.78%  best=91.78%  lr=1.00e-03
#   Epoch  12: loss=0.2432  val=89.37%  best=91.78%  lr=1.00e-03
#   Epoch  13: loss=0.2161  val=93.27%  best=93.27%  lr=1.00e-03
#   Epoch  14: loss=0.2079  val=91.11%  best=93.27%  lr=1.00e-03
#   Epoch  15: loss=0.2007  val=92.94%  best=93.27%  lr=1.00e-03
#   Epoch  16: loss=0.1984  val=91.69%  best=93.27%  lr=1.00e-03
#   Epoch  17: loss=0.1874  val=94.02%  best=94.02%  lr=1.00e-03
#   Epoch  18: loss=0.1814  val=92.94%  best=94.02%  lr=1.00e-03
#   Epoch  19: loss=0.1828  val=91.78%  best=94.02%  lr=1.00e-03
#   Epoch  20: loss=0.1785  val=93.69%  best=94.02%  lr=1.00e-03
#
#   Test accuracy: 86.07%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (20/44 folds)
#
# ============================================================
#   Fold 21/44  —  test: emg_gestures_24_U.mat
# ============================================================
#   Test  : emg_gestures_24_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8541  val=72.76%  best=72.76%  lr=1.00e-03
#   Epoch   2: loss=0.5692  val=85.05%  best=85.05%  lr=1.00e-03
#   Epoch   3: loss=0.4501  val=82.39%  best=85.05%  lr=1.00e-03
#   Epoch   4: loss=0.4186  val=90.70%  best=90.70%  lr=1.00e-03
#   Epoch   5: loss=0.3616  val=88.62%  best=90.70%  lr=1.00e-03
#   Epoch   6: loss=0.3376  val=88.54%  best=90.70%  lr=1.00e-03
#   Epoch   7: loss=0.3001  val=85.22%  best=90.70%  lr=1.00e-03
#   Epoch   8: loss=0.2801  val=89.62%  best=90.70%  lr=1.00e-03
#   Epoch   9: loss=0.2641  val=89.04%  best=90.70%  lr=1.00e-03
#   Early stopping at epoch 9.
#
#   Test accuracy: 95.00%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (21/44 folds)
#
# ============================================================
#   Fold 22/44  —  test: emg_gestures_25_U.mat
# ============================================================
#   Test  : emg_gestures_25_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8290  val=78.16%  best=78.16%  lr=1.00e-03
#   Epoch   2: loss=0.5668  val=85.47%  best=85.47%  lr=1.00e-03
#   Epoch   3: loss=0.4607  val=83.31%  best=85.47%  lr=1.00e-03
#   Epoch   4: loss=0.3971  val=84.97%  best=85.47%  lr=1.00e-03
#   Epoch   5: loss=0.3610  val=87.62%  best=87.62%  lr=1.00e-03
#   Epoch   6: loss=0.3325  val=87.21%  best=87.62%  lr=1.00e-03
#   Epoch   7: loss=0.2958  val=88.87%  best=88.87%  lr=1.00e-03
#   Epoch   8: loss=0.2830  val=87.29%  best=88.87%  lr=1.00e-03
#   Epoch   9: loss=0.2638  val=89.95%  best=89.95%  lr=1.00e-03
#   Epoch  10: loss=0.2533  val=88.12%  best=89.95%  lr=1.00e-03
#   Epoch  11: loss=0.2371  val=90.53%  best=90.53%  lr=1.00e-03
#   Epoch  12: loss=0.2282  val=88.70%  best=90.53%  lr=1.00e-03
#   Epoch  13: loss=0.2262  val=91.45%  best=91.45%  lr=1.00e-03
#   Epoch  14: loss=0.2026  val=91.53%  best=91.53%  lr=1.00e-03
#   Epoch  15: loss=0.1942  val=91.69%  best=91.69%  lr=1.00e-03
#   Epoch  16: loss=0.1908  val=92.77%  best=92.77%  lr=1.00e-03
#   Epoch  17: loss=0.1826  val=92.03%  best=92.77%  lr=1.00e-03
#   Epoch  18: loss=0.1884  val=91.78%  best=92.77%  lr=1.00e-03
#   Epoch  19: loss=0.1684  val=93.36%  best=93.36%  lr=1.00e-03
#   Epoch  20: loss=0.1576  val=95.18%  best=95.18%  lr=1.00e-03
#
#   Test accuracy: 66.07%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (22/44 folds)
#
# ============================================================
#   Fold 23/44  —  test: emg_gestures_26_U.mat
# ============================================================
#   Test  : emg_gestures_26_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8586  val=77.99%  best=77.99%  lr=1.00e-03
#   Epoch   2: loss=0.5518  val=79.82%  best=79.82%  lr=1.00e-03
#   Epoch   3: loss=0.4505  val=82.39%  best=82.39%  lr=1.00e-03
#   Epoch   4: loss=0.4045  val=86.88%  best=86.88%  lr=1.00e-03
#   Epoch   5: loss=0.3562  val=88.37%  best=88.37%  lr=1.00e-03
#   Epoch   6: loss=0.3341  val=85.13%  best=88.37%  lr=1.00e-03
#   Epoch   7: loss=0.3049  val=88.62%  best=88.62%  lr=1.00e-03
#   Epoch   8: loss=0.2660  val=88.87%  best=88.87%  lr=1.00e-03
#   Epoch   9: loss=0.2668  val=89.78%  best=89.78%  lr=1.00e-03
#   Epoch  10: loss=0.2480  val=90.95%  best=90.95%  lr=1.00e-03
#   Epoch  11: loss=0.2307  val=89.29%  best=90.95%  lr=1.00e-03
#   Epoch  12: loss=0.2307  val=92.61%  best=92.61%  lr=1.00e-03
#   Epoch  13: loss=0.2219  val=93.27%  best=93.27%  lr=1.00e-03
#   Epoch  14: loss=0.2125  val=91.20%  best=93.27%  lr=1.00e-03
#   Epoch  15: loss=0.1947  val=92.77%  best=93.27%  lr=1.00e-03
#   Epoch  16: loss=0.1903  val=92.03%  best=93.27%  lr=1.00e-03
#   Epoch  17: loss=0.1889  val=91.69%  best=93.27%  lr=1.00e-03
#   Epoch  18: loss=0.1770  val=95.18%  best=95.18%  lr=1.00e-03
#   Epoch  19: loss=0.1720  val=91.86%  best=95.18%  lr=1.00e-03
#   Epoch  20: loss=0.1729  val=93.60%  best=95.18%  lr=1.00e-03
#
#   Test accuracy: 56.07%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (23/44 folds)
#
# ============================================================
#   Fold 24/44  —  test: emg_gestures_27_U.mat
# ============================================================
#   Test  : emg_gestures_27_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8829  val=75.08%  best=75.08%  lr=1.00e-03
#   Epoch   2: loss=0.5715  val=79.24%  best=79.24%  lr=1.00e-03
#   Epoch   3: loss=0.4790  val=80.32%  best=80.32%  lr=1.00e-03
#   Epoch   4: loss=0.4028  val=84.80%  best=84.80%  lr=1.00e-03
#   Epoch   5: loss=0.3597  val=89.12%  best=89.12%  lr=1.00e-03
#   Epoch   6: loss=0.3444  val=89.37%  best=89.37%  lr=1.00e-03
#   Epoch   7: loss=0.3080  val=89.53%  best=89.53%  lr=1.00e-03
#   Epoch   8: loss=0.2968  val=91.11%  best=91.11%  lr=1.00e-03
#   Epoch   9: loss=0.2833  val=87.71%  best=91.11%  lr=1.00e-03
#   Epoch  10: loss=0.2614  val=90.03%  best=91.11%  lr=1.00e-03
#   Epoch  11: loss=0.2380  val=90.37%  best=91.11%  lr=1.00e-03
#   Epoch  12: loss=0.2337  val=91.45%  best=91.45%  lr=1.00e-03
#   Epoch  13: loss=0.2267  val=92.11%  best=92.11%  lr=1.00e-03
#   Epoch  14: loss=0.2156  val=93.69%  best=93.69%  lr=1.00e-03
#   Epoch  15: loss=0.2101  val=92.86%  best=93.69%  lr=1.00e-03
#   Epoch  16: loss=0.1925  val=92.61%  best=93.69%  lr=1.00e-03
#   Epoch  17: loss=0.1797  val=92.28%  best=93.69%  lr=1.00e-03
#   Epoch  18: loss=0.1835  val=93.19%  best=93.69%  lr=1.00e-03
#   Epoch  19: loss=0.1758  val=93.02%  best=93.69%  lr=1.00e-03
#   Early stopping at epoch 19.
#
#   Test accuracy: 97.50%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (24/44 folds)
#
# ============================================================
#   Fold 25/44  —  test: emg_gestures_29_U.mat
# ============================================================
#   Test  : emg_gestures_29_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8526  val=80.40%  best=80.40%  lr=1.00e-03
#   Epoch   2: loss=0.5653  val=81.81%  best=81.81%  lr=1.00e-03
#   Epoch   3: loss=0.4656  val=83.55%  best=83.55%  lr=1.00e-03
#   Epoch   4: loss=0.4153  val=87.87%  best=87.87%  lr=1.00e-03
#   Epoch   5: loss=0.3694  val=86.13%  best=87.87%  lr=1.00e-03
#   Epoch   6: loss=0.3367  val=86.46%  best=87.87%  lr=1.00e-03
#   Epoch   7: loss=0.3019  val=90.78%  best=90.78%  lr=1.00e-03
#   Epoch   8: loss=0.2913  val=88.79%  best=90.78%  lr=1.00e-03
#   Epoch   9: loss=0.2583  val=88.29%  best=90.78%  lr=1.00e-03
#   Epoch  10: loss=0.2567  val=91.94%  best=91.94%  lr=1.00e-03
#   Epoch  11: loss=0.2437  val=90.61%  best=91.94%  lr=1.00e-03
#   Epoch  12: loss=0.2325  val=92.69%  best=92.69%  lr=1.00e-03
#   Epoch  13: loss=0.2258  val=92.94%  best=92.94%  lr=1.00e-03
#   Epoch  14: loss=0.2148  val=92.11%  best=92.94%  lr=1.00e-03
#   Epoch  15: loss=0.2147  val=92.52%  best=92.94%  lr=1.00e-03
#   Epoch  16: loss=0.1955  val=92.36%  best=92.94%  lr=1.00e-03
#   Epoch  17: loss=0.1868  val=91.53%  best=92.94%  lr=1.00e-03
#   Epoch  18: loss=0.1801  val=93.19%  best=93.19%  lr=1.00e-03
#   Epoch  19: loss=0.1791  val=92.28%  best=93.19%  lr=1.00e-03
#   Epoch  20: loss=0.1754  val=94.52%  best=94.52%  lr=1.00e-03
#
#   Test accuracy: 93.57%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (25/44 folds)
#
# ============================================================
#   Fold 26/44  —  test: emg_gestures_30_U.mat
# ============================================================
#   Test  : emg_gestures_30_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8351  val=72.51%  best=72.51%  lr=1.00e-03
#   Epoch   2: loss=0.5548  val=82.56%  best=82.56%  lr=1.00e-03
#   Epoch   3: loss=0.4481  val=84.30%  best=84.30%  lr=1.00e-03
#   Epoch   4: loss=0.3956  val=86.63%  best=86.63%  lr=1.00e-03
#   Epoch   5: loss=0.3517  val=87.29%  best=87.29%  lr=1.00e-03
#   Epoch   6: loss=0.3179  val=87.79%  best=87.79%  lr=1.00e-03
#   Epoch   7: loss=0.2984  val=90.70%  best=90.70%  lr=1.00e-03
#   Epoch   8: loss=0.2752  val=89.12%  best=90.70%  lr=1.00e-03
#   Epoch   9: loss=0.2586  val=89.70%  best=90.70%  lr=1.00e-03
#   Epoch  10: loss=0.2517  val=89.37%  best=90.70%  lr=1.00e-03
#   Epoch  11: loss=0.2358  val=90.28%  best=90.70%  lr=1.00e-03
#   Epoch  12: loss=0.2296  val=92.52%  best=92.52%  lr=1.00e-03
#   Epoch  13: loss=0.2137  val=92.86%  best=92.86%  lr=1.00e-03
#   Epoch  14: loss=0.2129  val=90.70%  best=92.86%  lr=1.00e-03
#   Epoch  15: loss=0.1912  val=90.78%  best=92.86%  lr=1.00e-03
#   Epoch  16: loss=0.1980  val=90.78%  best=92.86%  lr=1.00e-03
#   Epoch  17: loss=0.1850  val=92.36%  best=92.86%  lr=1.00e-03
#   Epoch  18: loss=0.1815  val=92.44%  best=92.86%  lr=1.00e-03
#   Early stopping at epoch 18.
#
#   Test accuracy: 76.79%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (26/44 folds)
#
# ============================================================
#   Fold 27/44  —  test: emg_gestures_31_U.mat
# ============================================================
#   Test  : emg_gestures_31_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8653  val=75.50%  best=75.50%  lr=1.00e-03
#   Epoch   2: loss=0.5811  val=72.67%  best=75.50%  lr=1.00e-03
#   Epoch   3: loss=0.4751  val=79.32%  best=79.32%  lr=1.00e-03
#   Epoch   4: loss=0.4016  val=82.72%  best=82.72%  lr=1.00e-03
#   Epoch   5: loss=0.3529  val=86.63%  best=86.63%  lr=1.00e-03
#   Epoch   6: loss=0.3278  val=90.95%  best=90.95%  lr=1.00e-03
#   Epoch   7: loss=0.3002  val=90.53%  best=90.95%  lr=1.00e-03
#   Epoch   8: loss=0.2857  val=90.37%  best=90.95%  lr=1.00e-03
#   Epoch   9: loss=0.2698  val=89.37%  best=90.95%  lr=1.00e-03
#   Epoch  10: loss=0.2477  val=93.11%  best=93.11%  lr=1.00e-03
#   Epoch  11: loss=0.2430  val=92.86%  best=93.11%  lr=1.00e-03
#   Epoch  12: loss=0.2374  val=91.94%  best=93.11%  lr=1.00e-03
#   Epoch  13: loss=0.2200  val=91.45%  best=93.11%  lr=1.00e-03
#   Epoch  14: loss=0.2040  val=90.53%  best=93.11%  lr=1.00e-03
#   Epoch  15: loss=0.1996  val=93.69%  best=93.69%  lr=1.00e-03
#   Epoch  16: loss=0.1932  val=93.85%  best=93.85%  lr=1.00e-03
#   Epoch  17: loss=0.1859  val=93.44%  best=93.85%  lr=1.00e-03
#   Epoch  18: loss=0.1723  val=93.85%  best=93.85%  lr=1.00e-03
#   Epoch  19: loss=0.1696  val=91.03%  best=93.85%  lr=1.00e-03
#   Epoch  20: loss=0.1657  val=92.69%  best=93.85%  lr=1.00e-03
#
#   Test accuracy: 68.93%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (27/44 folds)
#
# ============================================================
#   Fold 28/44  —  test: emg_gestures_33_U.mat
# ============================================================
#   Test  : emg_gestures_33_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8701  val=68.11%  best=68.11%  lr=1.00e-03
#   Epoch   2: loss=0.5763  val=80.15%  best=80.15%  lr=1.00e-03
#   Epoch   3: loss=0.4781  val=81.06%  best=81.06%  lr=1.00e-03
#   Epoch   4: loss=0.4205  val=86.71%  best=86.71%  lr=1.00e-03
#   Epoch   5: loss=0.3784  val=86.88%  best=86.88%  lr=1.00e-03
#   Epoch   6: loss=0.3393  val=88.37%  best=88.37%  lr=1.00e-03
#   Epoch   7: loss=0.3111  val=88.37%  best=88.37%  lr=1.00e-03
#   Epoch   8: loss=0.2946  val=89.62%  best=89.62%  lr=1.00e-03
#   Epoch   9: loss=0.2766  val=90.45%  best=90.45%  lr=1.00e-03
#   Epoch  10: loss=0.2609  val=90.37%  best=90.45%  lr=1.00e-03
#   Epoch  11: loss=0.2419  val=89.95%  best=90.45%  lr=1.00e-03
#   Epoch  12: loss=0.2411  val=92.69%  best=92.69%  lr=1.00e-03
#   Epoch  13: loss=0.2155  val=87.29%  best=92.69%  lr=1.00e-03
#   Epoch  14: loss=0.2096  val=90.95%  best=92.69%  lr=1.00e-03
#   Epoch  15: loss=0.2033  val=87.04%  best=92.69%  lr=1.00e-03
#   Epoch  16: loss=0.2013  val=91.61%  best=92.69%  lr=1.00e-03
#   Epoch  17: loss=0.1922  val=90.45%  best=92.69%  lr=1.00e-03
#   Early stopping at epoch 17.
#
#   Test accuracy: 93.21%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (28/44 folds)
#
# ============================================================
#   Fold 29/44  —  test: emg_gestures_34_U.mat
# ============================================================
#   Test  : emg_gestures_34_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8180  val=76.08%  best=76.08%  lr=1.00e-03
#   Epoch   2: loss=0.5495  val=83.55%  best=83.55%  lr=1.00e-03
#   Epoch   3: loss=0.4571  val=88.62%  best=88.62%  lr=1.00e-03
#   Epoch   4: loss=0.4010  val=82.56%  best=88.62%  lr=1.00e-03
#   Epoch   5: loss=0.3708  val=88.04%  best=88.62%  lr=1.00e-03
#   Epoch   6: loss=0.3296  val=89.12%  best=89.12%  lr=1.00e-03
#   Epoch   7: loss=0.3093  val=85.63%  best=89.12%  lr=1.00e-03
#   Epoch   8: loss=0.2899  val=89.62%  best=89.62%  lr=1.00e-03
#   Epoch   9: loss=0.2787  val=92.94%  best=92.94%  lr=1.00e-03
#   Epoch  10: loss=0.2654  val=80.81%  best=92.94%  lr=1.00e-03
#   Epoch  11: loss=0.2496  val=92.28%  best=92.94%  lr=1.00e-03
#   Epoch  12: loss=0.2337  val=91.61%  best=92.94%  lr=1.00e-03
#   Epoch  13: loss=0.2189  val=90.37%  best=92.94%  lr=1.00e-03
#   Epoch  14: loss=0.2170  val=92.03%  best=92.94%  lr=1.00e-03
#   Early stopping at epoch 14.
#
#   Test accuracy: 72.86%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (29/44 folds)
#
# ============================================================
#   Fold 30/44  —  test: emg_gestures_35_U.mat
# ============================================================
#   Test  : emg_gestures_35_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8623  val=77.33%  best=77.33%  lr=1.00e-03
#   Epoch   2: loss=0.5582  val=78.82%  best=78.82%  lr=1.00e-03
#   Epoch   3: loss=0.4623  val=85.47%  best=85.47%  lr=1.00e-03
#   Epoch   4: loss=0.3989  val=88.79%  best=88.79%  lr=1.00e-03
#   Epoch   5: loss=0.3601  val=88.54%  best=88.79%  lr=1.00e-03
#   Epoch   6: loss=0.3248  val=88.95%  best=88.95%  lr=1.00e-03
#   Epoch   7: loss=0.3048  val=90.12%  best=90.12%  lr=1.00e-03
#   Epoch   8: loss=0.2926  val=90.95%  best=90.95%  lr=1.00e-03
#   Epoch   9: loss=0.2700  val=89.12%  best=90.95%  lr=1.00e-03
#   Epoch  10: loss=0.2515  val=90.70%  best=90.95%  lr=1.00e-03
#   Epoch  11: loss=0.2461  val=92.86%  best=92.86%  lr=1.00e-03
#   Epoch  12: loss=0.2374  val=90.20%  best=92.86%  lr=1.00e-03
#   Epoch  13: loss=0.2282  val=88.62%  best=92.86%  lr=1.00e-03
#   Epoch  14: loss=0.2178  val=88.04%  best=92.86%  lr=1.00e-03
#   Epoch  15: loss=0.2180  val=87.96%  best=92.86%  lr=1.00e-03
#   Epoch  16: loss=0.1965  val=93.36%  best=93.36%  lr=1.00e-03
#   Epoch  17: loss=0.2010  val=91.53%  best=93.36%  lr=1.00e-03
#   Epoch  18: loss=0.1837  val=93.11%  best=93.36%  lr=1.00e-03
#   Epoch  19: loss=0.1880  val=90.86%  best=93.36%  lr=1.00e-03
#   Epoch  20: loss=0.1768  val=91.53%  best=93.36%  lr=1.00e-03
#
#   Test accuracy: 96.79%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (30/44 folds)
#
# ============================================================
#   Fold 31/44  —  test: emg_gestures_36_U.mat
# ============================================================
#   Test  : emg_gestures_36_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8509  val=77.24%  best=77.24%  lr=1.00e-03
#   Epoch   2: loss=0.5537  val=82.39%  best=82.39%  lr=1.00e-03
#   Epoch   3: loss=0.4602  val=84.14%  best=84.14%  lr=1.00e-03
#   Epoch   4: loss=0.4026  val=83.64%  best=84.14%  lr=1.00e-03
#   Epoch   5: loss=0.3401  val=86.63%  best=86.63%  lr=1.00e-03
#   Epoch   6: loss=0.3330  val=88.79%  best=88.79%  lr=1.00e-03
#   Epoch   7: loss=0.2990  val=90.53%  best=90.53%  lr=1.00e-03
#   Epoch   8: loss=0.2797  val=90.45%  best=90.53%  lr=1.00e-03
#   Epoch   9: loss=0.2653  val=91.45%  best=91.45%  lr=1.00e-03
#   Epoch  10: loss=0.2480  val=88.95%  best=91.45%  lr=1.00e-03
#   Epoch  11: loss=0.2411  val=90.03%  best=91.45%  lr=1.00e-03
#   Epoch  12: loss=0.2226  val=89.95%  best=91.45%  lr=1.00e-03
#   Epoch  13: loss=0.2264  val=89.29%  best=91.45%  lr=1.00e-03
#   Epoch  14: loss=0.2194  val=92.11%  best=92.11%  lr=1.00e-03
#   Epoch  15: loss=0.1963  val=90.12%  best=92.11%  lr=1.00e-03
#   Epoch  16: loss=0.2011  val=91.20%  best=92.11%  lr=1.00e-03
#   Epoch  17: loss=0.1790  val=92.44%  best=92.44%  lr=1.00e-03
#   Epoch  18: loss=0.1774  val=94.27%  best=94.27%  lr=1.00e-03
#   Epoch  19: loss=0.1727  val=90.53%  best=94.27%  lr=1.00e-03
#   Epoch  20: loss=0.1747  val=93.36%  best=94.27%  lr=1.00e-03
#
#   Test accuracy: 88.21%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (31/44 folds)
#
# ============================================================
#   Fold 32/44  —  test: emg_gestures_38_U.mat
# ============================================================
#   Test  : emg_gestures_38_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8556  val=80.40%  best=80.40%  lr=1.00e-03
#   Epoch   2: loss=0.5682  val=79.90%  best=80.40%  lr=1.00e-03
#   Epoch   3: loss=0.4641  val=85.13%  best=85.13%  lr=1.00e-03
#   Epoch   4: loss=0.3908  val=89.20%  best=89.20%  lr=1.00e-03
#   Epoch   5: loss=0.3522  val=86.88%  best=89.20%  lr=1.00e-03
#   Epoch   6: loss=0.3344  val=83.47%  best=89.20%  lr=1.00e-03
#   Epoch   7: loss=0.3115  val=91.20%  best=91.20%  lr=1.00e-03
#   Epoch   8: loss=0.2650  val=89.78%  best=91.20%  lr=1.00e-03
#   Epoch   9: loss=0.2718  val=86.71%  best=91.20%  lr=1.00e-03
#   Epoch  10: loss=0.2464  val=90.53%  best=91.20%  lr=1.00e-03
#   Epoch  11: loss=0.2348  val=90.70%  best=91.20%  lr=1.00e-03
#   Epoch  12: loss=0.2279  val=92.44%  best=92.44%  lr=1.00e-03
#   Epoch  13: loss=0.2104  val=92.61%  best=92.61%  lr=1.00e-03
#   Epoch  14: loss=0.2101  val=90.37%  best=92.61%  lr=1.00e-03
#   Epoch  15: loss=0.1991  val=90.61%  best=92.61%  lr=1.00e-03
#   Epoch  16: loss=0.1959  val=91.53%  best=92.61%  lr=1.00e-03
#   Epoch  17: loss=0.1851  val=92.77%  best=92.77%  lr=1.00e-03
#   Epoch  18: loss=0.1770  val=92.61%  best=92.77%  lr=1.00e-03
#   Epoch  19: loss=0.1786  val=92.94%  best=92.94%  lr=1.00e-03
#   Epoch  20: loss=0.1599  val=89.62%  best=92.94%  lr=1.00e-03
#
#   Test accuracy: 86.43%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (32/44 folds)
#
# ============================================================
#   Fold 33/44  —  test: emg_gestures_39_U.mat
# ============================================================
#   Test  : emg_gestures_39_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8616  val=69.68%  best=69.68%  lr=1.00e-03
#   Epoch   2: loss=0.5575  val=81.89%  best=81.89%  lr=1.00e-03
#   Epoch   3: loss=0.4636  val=85.38%  best=85.38%  lr=1.00e-03
#   Epoch   4: loss=0.4048  val=87.54%  best=87.54%  lr=1.00e-03
#   Epoch   5: loss=0.3500  val=83.14%  best=87.54%  lr=1.00e-03
#   Epoch   6: loss=0.3222  val=90.61%  best=90.61%  lr=1.00e-03
#   Epoch   7: loss=0.2989  val=88.62%  best=90.61%  lr=1.00e-03
#   Epoch   8: loss=0.2840  val=89.95%  best=90.61%  lr=1.00e-03
#   Epoch   9: loss=0.2634  val=89.95%  best=90.61%  lr=1.00e-03
#   Epoch  10: loss=0.2517  val=93.36%  best=93.36%  lr=1.00e-03
#   Epoch  11: loss=0.2327  val=90.53%  best=93.36%  lr=1.00e-03
#   Epoch  12: loss=0.2232  val=90.12%  best=93.36%  lr=1.00e-03
#   Epoch  13: loss=0.2202  val=93.77%  best=93.77%  lr=1.00e-03
#   Epoch  14: loss=0.2019  val=89.20%  best=93.77%  lr=1.00e-03
#   Epoch  15: loss=0.2069  val=91.11%  best=93.77%  lr=1.00e-03
#   Epoch  16: loss=0.1880  val=92.94%  best=93.77%  lr=1.00e-03
#   Epoch  17: loss=0.1813  val=86.63%  best=93.77%  lr=1.00e-03
#   Epoch  18: loss=0.1746  val=91.28%  best=93.77%  lr=1.00e-03
#   Early stopping at epoch 18.
#
#   Test accuracy: 75.71%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (33/44 folds)
#
# ============================================================
#   Fold 34/44  —  test: emg_gestures_42_U.mat
# ============================================================
#   Test  : emg_gestures_42_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8580  val=74.17%  best=74.17%  lr=1.00e-03
#   Epoch   2: loss=0.5658  val=81.81%  best=81.81%  lr=1.00e-03
#   Epoch   3: loss=0.4616  val=84.88%  best=84.88%  lr=1.00e-03
#   Epoch   4: loss=0.4070  val=89.53%  best=89.53%  lr=1.00e-03
#   Epoch   5: loss=0.3609  val=88.12%  best=89.53%  lr=1.00e-03
#   Epoch   6: loss=0.3229  val=85.71%  best=89.53%  lr=1.00e-03
#   Epoch   7: loss=0.3165  val=88.70%  best=89.53%  lr=1.00e-03
#   Epoch   8: loss=0.2852  val=90.53%  best=90.53%  lr=1.00e-03
#   Epoch   9: loss=0.2661  val=90.78%  best=90.78%  lr=1.00e-03
#   Epoch  10: loss=0.2557  val=92.52%  best=92.52%  lr=1.00e-03
#   Epoch  11: loss=0.2331  val=90.61%  best=92.52%  lr=1.00e-03
#   Epoch  12: loss=0.2411  val=89.53%  best=92.52%  lr=1.00e-03
#   Epoch  13: loss=0.2242  val=93.19%  best=93.19%  lr=1.00e-03
#   Epoch  14: loss=0.2108  val=91.45%  best=93.19%  lr=1.00e-03
#   Epoch  15: loss=0.2081  val=85.88%  best=93.19%  lr=1.00e-03
#   Epoch  16: loss=0.1992  val=92.36%  best=93.19%  lr=1.00e-03
#   Epoch  17: loss=0.1869  val=92.19%  best=93.19%  lr=1.00e-03
#   Epoch  18: loss=0.1796  val=90.86%  best=93.19%  lr=1.00e-03
#   Early stopping at epoch 18.
#
#   Test accuracy: 81.43%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (34/44 folds)
#
# ============================================================
#   Fold 35/44  —  test: emg_gestures_43_U.mat
# ============================================================
#   Test  : emg_gestures_43_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8278  val=81.64%  best=81.64%  lr=1.00e-03
#   Epoch   2: loss=0.5467  val=84.22%  best=84.22%  lr=1.00e-03
#   Epoch   3: loss=0.4564  val=86.71%  best=86.71%  lr=1.00e-03
#   Epoch   4: loss=0.3972  val=89.04%  best=89.04%  lr=1.00e-03
#   Epoch   5: loss=0.3484  val=88.54%  best=89.04%  lr=1.00e-03
#   Epoch   6: loss=0.3261  val=90.86%  best=90.86%  lr=1.00e-03
#   Epoch   7: loss=0.2967  val=89.04%  best=90.86%  lr=1.00e-03
#   Epoch   8: loss=0.2879  val=92.11%  best=92.11%  lr=1.00e-03
#   Epoch   9: loss=0.2595  val=93.52%  best=93.52%  lr=1.00e-03
#   Epoch  10: loss=0.2518  val=92.11%  best=93.52%  lr=1.00e-03
#   Epoch  11: loss=0.2374  val=90.20%  best=93.52%  lr=1.00e-03
#   Epoch  12: loss=0.2216  val=89.87%  best=93.52%  lr=1.00e-03
#   Epoch  13: loss=0.2242  val=92.19%  best=93.52%  lr=1.00e-03
#   Epoch  14: loss=0.2037  val=93.52%  best=93.52%  lr=1.00e-03
#   Epoch  15: loss=0.2038  val=91.36%  best=93.52%  lr=1.00e-03
#   Epoch  16: loss=0.1433  val=95.85%  best=95.85%  lr=5.00e-04
#   Epoch  17: loss=0.1378  val=94.68%  best=95.85%  lr=5.00e-04
#   Epoch  18: loss=0.1293  val=95.60%  best=95.85%  lr=5.00e-04
#   Epoch  19: loss=0.1305  val=95.02%  best=95.85%  lr=5.00e-04
#   Epoch  20: loss=0.1217  val=95.43%  best=95.85%  lr=5.00e-04
#
#   Test accuracy: 84.64%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (35/44 folds)
#
# ============================================================
#   Fold 36/44  —  test: emg_gestures_45_U.mat
# ============================================================
#   Test  : emg_gestures_45_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8374  val=77.74%  best=77.74%  lr=1.00e-03
#   Epoch   2: loss=0.5540  val=81.31%  best=81.31%  lr=1.00e-03
#   Epoch   3: loss=0.4678  val=82.31%  best=82.31%  lr=1.00e-03
#   Epoch   4: loss=0.3988  val=86.46%  best=86.46%  lr=1.00e-03
#   Epoch   5: loss=0.3581  val=87.71%  best=87.71%  lr=1.00e-03
#   Epoch   6: loss=0.3446  val=88.12%  best=88.12%  lr=1.00e-03
#   Epoch   7: loss=0.3107  val=89.78%  best=89.78%  lr=1.00e-03
#   Epoch   8: loss=0.2907  val=91.03%  best=91.03%  lr=1.00e-03
#   Epoch   9: loss=0.2721  val=86.88%  best=91.03%  lr=1.00e-03
#   Epoch  10: loss=0.2473  val=91.86%  best=91.86%  lr=1.00e-03
#   Epoch  11: loss=0.2554  val=92.52%  best=92.52%  lr=1.00e-03
#   Epoch  12: loss=0.2304  val=86.38%  best=92.52%  lr=1.00e-03
#   Epoch  13: loss=0.2299  val=87.71%  best=92.52%  lr=1.00e-03
#   Epoch  14: loss=0.2165  val=91.78%  best=92.52%  lr=1.00e-03
#   Epoch  15: loss=0.2063  val=90.12%  best=92.52%  lr=1.00e-03
#   Epoch  16: loss=0.1947  val=90.70%  best=92.52%  lr=1.00e-03
#   Early stopping at epoch 16.
#
#   Test accuracy: 84.29%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (36/44 folds)
#
# ============================================================
#   Fold 37/44  —  test: emg_gestures_46_U.mat
# ============================================================
#   Test  : emg_gestures_46_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8066  val=80.48%  best=80.48%  lr=1.00e-03
#   Epoch   2: loss=0.5735  val=82.89%  best=82.89%  lr=1.00e-03
#   Epoch   3: loss=0.4767  val=86.13%  best=86.13%  lr=1.00e-03
#   Epoch   4: loss=0.4088  val=89.12%  best=89.12%  lr=1.00e-03
#   Epoch   5: loss=0.3720  val=85.30%  best=89.12%  lr=1.00e-03
#   Epoch   6: loss=0.3473  val=89.04%  best=89.12%  lr=1.00e-03
#   Epoch   7: loss=0.3111  val=90.03%  best=90.03%  lr=1.00e-03
#   Epoch   8: loss=0.2913  val=91.28%  best=91.28%  lr=1.00e-03
#   Epoch   9: loss=0.2671  val=90.45%  best=91.28%  lr=1.00e-03
#   Epoch  10: loss=0.2524  val=89.45%  best=91.28%  lr=1.00e-03
#   Epoch  11: loss=0.2571  val=93.11%  best=93.11%  lr=1.00e-03
#   Epoch  12: loss=0.2380  val=91.11%  best=93.11%  lr=1.00e-03
#   Epoch  13: loss=0.2293  val=91.11%  best=93.11%  lr=1.00e-03
#   Epoch  14: loss=0.2155  val=88.70%  best=93.11%  lr=1.00e-03
#   Epoch  15: loss=0.2123  val=92.69%  best=93.11%  lr=1.00e-03
#   Epoch  16: loss=0.1900  val=92.52%  best=93.11%  lr=1.00e-03
#   Early stopping at epoch 16.
#
#   Test accuracy: 89.29%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (37/44 folds)
#
# ============================================================
#   Fold 38/44  —  test: emg_gestures_47_U.mat
# ============================================================
#   Test  : emg_gestures_47_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8566  val=77.08%  best=77.08%  lr=1.00e-03
#   Epoch   2: loss=0.5442  val=86.38%  best=86.38%  lr=1.00e-03
#   Epoch   3: loss=0.4513  val=80.40%  best=86.38%  lr=1.00e-03
#   Epoch   4: loss=0.3911  val=89.29%  best=89.29%  lr=1.00e-03
#   Epoch   5: loss=0.3603  val=85.71%  best=89.29%  lr=1.00e-03
#   Epoch   6: loss=0.3308  val=91.45%  best=91.45%  lr=1.00e-03
#   Epoch   7: loss=0.2963  val=90.28%  best=91.45%  lr=1.00e-03
#   Epoch   8: loss=0.2889  val=91.20%  best=91.45%  lr=1.00e-03
#   Epoch   9: loss=0.2621  val=90.45%  best=91.45%  lr=1.00e-03
#   Epoch  10: loss=0.2504  val=90.95%  best=91.45%  lr=1.00e-03
#   Epoch  11: loss=0.2435  val=91.94%  best=91.94%  lr=1.00e-03
#   Epoch  12: loss=0.2294  val=93.27%  best=93.27%  lr=1.00e-03
#   Epoch  13: loss=0.2159  val=90.78%  best=93.27%  lr=1.00e-03
#   Epoch  14: loss=0.2147  val=92.77%  best=93.27%  lr=1.00e-03
#   Epoch  15: loss=0.2002  val=89.53%  best=93.27%  lr=1.00e-03
#   Epoch  16: loss=0.2094  val=89.70%  best=93.27%  lr=1.00e-03
#   Epoch  17: loss=0.1923  val=92.52%  best=93.27%  lr=1.00e-03
#   Early stopping at epoch 17.
#
#   Test accuracy: 61.07%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (38/44 folds)
#
# ============================================================
#   Fold 39/44  —  test: emg_gestures_48_U.mat
# ============================================================
#   Test  : emg_gestures_48_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8535  val=77.57%  best=77.57%  lr=1.00e-03
#   Epoch   2: loss=0.5664  val=82.14%  best=82.14%  lr=1.00e-03
#   Epoch   3: loss=0.4719  val=83.47%  best=83.47%  lr=1.00e-03
#   Epoch   4: loss=0.4039  val=86.71%  best=86.71%  lr=1.00e-03
#   Epoch   5: loss=0.3710  val=89.29%  best=89.29%  lr=1.00e-03
#   Epoch   6: loss=0.3217  val=88.29%  best=89.29%  lr=1.00e-03
#   Epoch   7: loss=0.3060  val=88.12%  best=89.29%  lr=1.00e-03
#   Epoch   8: loss=0.2771  val=90.78%  best=90.78%  lr=1.00e-03
#   Epoch   9: loss=0.2748  val=90.70%  best=90.78%  lr=1.00e-03
#   Epoch  10: loss=0.2581  val=89.70%  best=90.78%  lr=1.00e-03
#   Epoch  11: loss=0.2364  val=92.86%  best=92.86%  lr=1.00e-03
#   Epoch  12: loss=0.2301  val=90.70%  best=92.86%  lr=1.00e-03
#   Epoch  13: loss=0.2289  val=91.36%  best=92.86%  lr=1.00e-03
#   Epoch  14: loss=0.2060  val=91.11%  best=92.86%  lr=1.00e-03
#   Epoch  15: loss=0.2058  val=90.53%  best=92.86%  lr=1.00e-03
#   Epoch  16: loss=0.2057  val=93.94%  best=93.94%  lr=1.00e-03
#   Epoch  17: loss=0.1945  val=92.44%  best=93.94%  lr=1.00e-03
#   Epoch  18: loss=0.1873  val=90.45%  best=93.94%  lr=1.00e-03
#   Epoch  19: loss=0.1885  val=92.03%  best=93.94%  lr=1.00e-03
#   Epoch  20: loss=0.1699  val=93.77%  best=93.94%  lr=1.00e-03
#
#   Test accuracy: 99.29%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (39/44 folds)
#
# ============================================================
#   Fold 40/44  —  test: emg_gestures_49_U.mat
# ============================================================
#   Test  : emg_gestures_49_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8972  val=64.78%  best=64.78%  lr=1.00e-03
#   Epoch   2: loss=0.5953  val=81.31%  best=81.31%  lr=1.00e-03
#   Epoch   3: loss=0.5031  val=82.06%  best=82.06%  lr=1.00e-03
#   Epoch   4: loss=0.4371  val=88.70%  best=88.70%  lr=1.00e-03
#   Epoch   5: loss=0.3832  val=86.71%  best=88.70%  lr=1.00e-03
#   Epoch   6: loss=0.3411  val=90.20%  best=90.20%  lr=1.00e-03
#   Epoch   7: loss=0.3139  val=84.63%  best=90.20%  lr=1.00e-03
#   Epoch   8: loss=0.3096  val=87.54%  best=90.20%  lr=1.00e-03
#   Epoch   9: loss=0.2746  val=90.61%  best=90.61%  lr=1.00e-03
#   Epoch  10: loss=0.2634  val=90.86%  best=90.86%  lr=1.00e-03
#   Epoch  11: loss=0.2533  val=90.70%  best=90.86%  lr=1.00e-03
#   Epoch  12: loss=0.2377  val=88.95%  best=90.86%  lr=1.00e-03
#   Epoch  13: loss=0.2342  val=91.78%  best=91.78%  lr=1.00e-03
#   Epoch  14: loss=0.2316  val=89.45%  best=91.78%  lr=1.00e-03
#   Epoch  15: loss=0.2125  val=90.95%  best=91.78%  lr=1.00e-03
#   Epoch  16: loss=0.2046  val=92.11%  best=92.11%  lr=1.00e-03
#   Epoch  17: loss=0.1907  val=91.78%  best=92.11%  lr=1.00e-03
#   Epoch  18: loss=0.1807  val=94.44%  best=94.44%  lr=1.00e-03
#   Epoch  19: loss=0.1863  val=93.36%  best=94.44%  lr=1.00e-03
#   Epoch  20: loss=0.1749  val=93.94%  best=94.44%  lr=1.00e-03
#
#   Test accuracy: 93.93%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (40/44 folds)
#
# ============================================================
#   Fold 41/44  —  test: emg_gestures_50_U.mat
# ============================================================
#   Test  : emg_gestures_50_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8692  val=70.10%  best=70.10%  lr=1.00e-03
#   Epoch   2: loss=0.5669  val=80.90%  best=80.90%  lr=1.00e-03
#   Epoch   3: loss=0.4619  val=84.80%  best=84.80%  lr=1.00e-03
#   Epoch   4: loss=0.4143  val=81.64%  best=84.80%  lr=1.00e-03
#   Epoch   5: loss=0.3565  val=89.04%  best=89.04%  lr=1.00e-03
#   Epoch   6: loss=0.3414  val=83.22%  best=89.04%  lr=1.00e-03
#   Epoch   7: loss=0.3110  val=86.88%  best=89.04%  lr=1.00e-03
#   Epoch   8: loss=0.2873  val=90.86%  best=90.86%  lr=1.00e-03
#   Epoch   9: loss=0.2712  val=90.78%  best=90.86%  lr=1.00e-03
#   Epoch  10: loss=0.2666  val=89.70%  best=90.86%  lr=1.00e-03
#   Epoch  11: loss=0.2448  val=90.12%  best=90.86%  lr=1.00e-03
#   Epoch  12: loss=0.2368  val=83.47%  best=90.86%  lr=1.00e-03
#   Epoch  13: loss=0.2135  val=92.52%  best=92.52%  lr=1.00e-03
#   Epoch  14: loss=0.2229  val=91.78%  best=92.52%  lr=1.00e-03
#   Epoch  15: loss=0.2119  val=92.03%  best=92.52%  lr=1.00e-03
#   Epoch  16: loss=0.1963  val=92.44%  best=92.52%  lr=1.00e-03
#   Epoch  17: loss=0.1930  val=93.19%  best=93.19%  lr=1.00e-03
#   Epoch  18: loss=0.1805  val=92.69%  best=93.19%  lr=1.00e-03
#   Epoch  19: loss=0.1801  val=94.27%  best=94.27%  lr=1.00e-03
#   Epoch  20: loss=0.1716  val=88.79%  best=94.27%  lr=1.00e-03
#
#   Test accuracy: 94.29%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (41/44 folds)
#
# ============================================================
#   Fold 42/44  —  test: emg_gestures_51_U.mat
# ============================================================
#   Test  : emg_gestures_51_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8245  val=78.24%  best=78.24%  lr=1.00e-03
#   Epoch   2: loss=0.5380  val=80.56%  best=80.56%  lr=1.00e-03
#   Epoch   3: loss=0.4406  val=84.72%  best=84.72%  lr=1.00e-03
#   Epoch   4: loss=0.3960  val=87.46%  best=87.46%  lr=1.00e-03
#   Epoch   5: loss=0.3538  val=87.54%  best=87.54%  lr=1.00e-03
#   Epoch   6: loss=0.3192  val=90.20%  best=90.20%  lr=1.00e-03
#   Epoch   7: loss=0.3024  val=91.61%  best=91.61%  lr=1.00e-03
#   Epoch   8: loss=0.2858  val=89.53%  best=91.61%  lr=1.00e-03
#   Epoch   9: loss=0.2632  val=91.61%  best=91.61%  lr=1.00e-03
#   Epoch  10: loss=0.2471  val=89.87%  best=91.61%  lr=1.00e-03
#   Epoch  11: loss=0.2434  val=92.28%  best=92.28%  lr=1.00e-03
#   Epoch  12: loss=0.2375  val=92.94%  best=92.94%  lr=1.00e-03
#   Epoch  13: loss=0.2155  val=93.60%  best=93.60%  lr=1.00e-03
#   Epoch  14: loss=0.2083  val=93.02%  best=93.60%  lr=1.00e-03
#   Epoch  15: loss=0.2057  val=93.52%  best=93.60%  lr=1.00e-03
#   Epoch  16: loss=0.2003  val=90.03%  best=93.60%  lr=1.00e-03
#   Epoch  17: loss=0.1820  val=91.86%  best=93.60%  lr=1.00e-03
#   Epoch  18: loss=0.1701  val=93.69%  best=93.69%  lr=1.00e-03
#   Epoch  19: loss=0.1793  val=91.53%  best=93.69%  lr=1.00e-03
#   Epoch  20: loss=0.1613  val=93.60%  best=93.69%  lr=1.00e-03
#
#   Test accuracy: 77.14%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (42/44 folds)
#
# ============================================================
#   Fold 43/44  —  test: emg_gestures_53_U.mat
# ============================================================
#   Test  : emg_gestures_53_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8498  val=67.94%  best=67.94%  lr=1.00e-03
#   Epoch   2: loss=0.5544  val=81.81%  best=81.81%  lr=1.00e-03
#   Epoch   3: loss=0.4664  val=85.22%  best=85.22%  lr=1.00e-03
#   Epoch   4: loss=0.3857  val=86.05%  best=86.05%  lr=1.00e-03
#   Epoch   5: loss=0.3597  val=89.12%  best=89.12%  lr=1.00e-03
#   Epoch   6: loss=0.3343  val=87.79%  best=89.12%  lr=1.00e-03
#   Epoch   7: loss=0.3061  val=87.29%  best=89.12%  lr=1.00e-03
#   Epoch   8: loss=0.2954  val=88.70%  best=89.12%  lr=1.00e-03
#   Epoch   9: loss=0.2691  val=91.28%  best=91.28%  lr=1.00e-03
#   Epoch  10: loss=0.2529  val=88.62%  best=91.28%  lr=1.00e-03
#   Epoch  11: loss=0.2519  val=89.87%  best=91.28%  lr=1.00e-03
#   Epoch  12: loss=0.2342  val=90.61%  best=91.28%  lr=1.00e-03
#   Epoch  13: loss=0.2250  val=91.11%  best=91.28%  lr=1.00e-03
#   Epoch  14: loss=0.2125  val=90.45%  best=91.28%  lr=1.00e-03
#   Epoch  15: loss=0.2168  val=92.52%  best=92.52%  lr=1.00e-03
#   Epoch  16: loss=0.1999  val=88.70%  best=92.52%  lr=1.00e-03
#   Epoch  17: loss=0.1957  val=91.45%  best=92.52%  lr=1.00e-03
#   Epoch  18: loss=0.1877  val=91.28%  best=92.52%  lr=1.00e-03
#   Epoch  19: loss=0.1725  val=93.77%  best=93.77%  lr=1.00e-03
#   Epoch  20: loss=0.1770  val=93.85%  best=93.85%  lr=1.00e-03
#
#   Test accuracy: 91.79%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (43/44 folds)
#
# ============================================================
#   Fold 44/44  —  test: emg_gestures_54_U.mat
# ============================================================
#   Test  : emg_gestures_54_U.mat  (280 reps)
#   Train : 10836 reps  |  Val: 1204 reps  (43 subjects, 90/10 split)
#   Epoch   1: loss=0.8809  val=73.09%  best=73.09%  lr=1.00e-03
#   Epoch   2: loss=0.5715  val=82.06%  best=82.06%  lr=1.00e-03
#   Epoch   3: loss=0.4616  val=81.15%  best=82.06%  lr=1.00e-03
#   Epoch   4: loss=0.3935  val=88.04%  best=88.04%  lr=1.00e-03
#   Epoch   5: loss=0.3610  val=83.06%  best=88.04%  lr=1.00e-03
#   Epoch   6: loss=0.3259  val=89.53%  best=89.53%  lr=1.00e-03
#   Epoch   7: loss=0.2956  val=90.86%  best=90.86%  lr=1.00e-03
#   Epoch   8: loss=0.2814  val=88.87%  best=90.86%  lr=1.00e-03
#   Epoch   9: loss=0.2685  val=91.28%  best=91.28%  lr=1.00e-03
#   Epoch  10: loss=0.2540  val=92.28%  best=92.28%  lr=1.00e-03
#   Epoch  11: loss=0.2423  val=91.53%  best=92.28%  lr=1.00e-03
#   Epoch  12: loss=0.2332  val=92.28%  best=92.28%  lr=1.00e-03
#   Epoch  13: loss=0.2125  val=88.21%  best=92.28%  lr=1.00e-03
#   Epoch  14: loss=0.2072  val=91.61%  best=92.28%  lr=1.00e-03
#   Epoch  15: loss=0.2002  val=92.52%  best=92.52%  lr=1.00e-03
#   Epoch  16: loss=0.1922  val=91.45%  best=92.52%  lr=1.00e-03
#   Epoch  17: loss=0.1883  val=92.36%  best=92.52%  lr=1.00e-03
#   Epoch  18: loss=0.1875  val=91.36%  best=92.52%  lr=1.00e-03
#   Epoch  19: loss=0.1745  val=94.44%  best=94.44%  lr=1.00e-03
#   Epoch  20: loss=0.1622  val=93.52%  best=94.44%  lr=1.00e-03
#
#   Test accuracy: 90.71%
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (44/44 folds)
#
# ============================================================
#   All folds complete.
# ============================================================
# Log updated → /Users/chrisdollo/Documents/Research/putEMG prime/generalizable/baseline_models/deep_learning_approach/results_log.txt  (44/44 folds)

# %% [markdown]
# ---
# ## Results

# %%
# ── Print log ─────────────────────────────────────────────────────────────────
if os.path.exists(LOG_PATH):
    with open(LOG_PATH) as f:
        print(f.read())
else:
    print("No results yet — run the training loop first.")

# ── Bar chart ─────────────────────────────────────────────────────────────────
checkpoints = []
for fname in sorted(os.listdir(WEIGHTS_DIR)):
    if not fname.endswith('.pt'):
        continue
    ckpt = torch.load(os.path.join(WEIGHTS_DIR, fname), map_location='cpu', weights_only=False)
    if 'subject' not in ckpt:   # skip old-format checkpoints
        continue
    checkpoints.append(ckpt)

if checkpoints:
    sids  = [subject_id(c['subject']) for c in checkpoints]
    accs  = [c['test_acc'] * 100 for c in checkpoints]
    mean  = np.mean(accs)

    fig, ax = plt.subplots(figsize=(max(10, len(sids) * 0.45), 4))
    ax.bar(sids, accs, color='steelblue')
    ax.axhline(mean, color='tomato', linestyle='--', linewidth=1.5, label=f'Mean {mean:.1f}%')
    ax.set_ylim(0, 105)
    ax.set_xlabel('Test Subject')
    ax.set_ylabel('Test Accuracy (%)')
    ax.set_title(f'EMG_TCN LOSO — Per-Subject Accuracy  ({len(checkpoints)}/{len(subjects)} folds)')
    ax.legend()
    plt.xticks(rotation=45, ha='right', fontsize=8)
    plt.tight_layout()
    plt.show()
# Out:
# putEMG — EMG_TCN LOSO Results
# ====================================================================
# Subject                       Test Acc    Val Acc   Epoch  Date
# --------------------------------------------------------------------
# emg_gestures_03_U.mat           98.21%     94.85%      20  2026-04-20
# emg_gestures_04_U.mat           71.07%     92.69%       9  2026-04-20
# emg_gestures_05_U.mat           67.14%     94.68%      17  2026-04-20
# emg_gestures_06_U.mat           53.93%     94.02%      11  2026-04-20
# emg_gestures_07_U.mat           63.57%     91.03%       5  2026-04-20
# emg_gestures_08_U.mat           73.21%     94.10%      19  2026-04-20
# emg_gestures_09_U.mat           82.50%     94.10%      20  2026-04-20
# emg_gestures_10_U.mat           88.93%     92.11%       6  2026-04-20
# emg_gestures_11_U.mat           73.57%     94.02%      19  2026-04-20
# emg_gestures_12_U.mat           92.50%     94.52%      20  2026-04-20
# emg_gestures_13_U.mat           79.29%     95.43%      16  2026-04-20
# emg_gestures_14_U.mat           99.29%     95.18%      20  2026-04-20
# emg_gestures_15_U.mat           85.00%     93.60%      13  2026-04-20
# emg_gestures_16_U.mat           62.50%     94.10%      18  2026-04-20
# emg_gestures_17_U.mat           65.36%     93.94%      20  2026-04-20
# emg_gestures_18_U.mat           71.07%     91.03%       5  2026-04-20
# emg_gestures_19_U.mat           70.36%     93.44%       8  2026-04-20
# emg_gestures_20_U.mat           76.79%     94.19%      18  2026-04-20
# emg_gestures_22_U.mat           78.21%     92.03%       8  2026-04-20
# emg_gestures_23_U.mat           86.07%     94.02%      17  2026-04-21
# emg_gestures_24_U.mat           95.00%     90.70%       4  2026-04-21
# emg_gestures_25_U.mat           66.07%     95.18%      20  2026-04-21
# emg_gestures_26_U.mat           56.07%     95.18%      18  2026-04-21
# emg_gestures_27_U.mat           97.50%     93.69%      14  2026-04-21
# emg_gestures_29_U.mat           93.57%     94.52%      20  2026-04-21
# emg_gestures_30_U.mat           76.79%     92.86%      13  2026-04-21
# emg_gestures_31_U.mat           68.93%     93.85%      16  2026-04-21
# emg_gestures_33_U.mat           93.21%     92.69%      12  2026-04-21
# emg_gestures_34_U.mat           72.86%     92.94%       9  2026-04-21
# emg_gestures_35_U.mat           96.79%     93.36%      16  2026-04-21
# emg_gestures_36_U.mat           88.21%     94.27%      18  2026-04-21
# emg_gestures_38_U.mat           86.43%     92.94%      19  2026-04-21
# emg_gestures_39_U.mat           75.71%     93.77%      13  2026-04-21
# emg_gestures_42_U.mat           81.43%     93.19%      13  2026-04-21
# emg_gestures_43_U.mat           84.64%     95.85%      16  2026-04-21
# emg_gestures_45_U.mat           84.29%     92.52%      11  2026-04-21
# emg_gestures_46_U.mat           89.29%     93.11%      11  2026-04-21
# emg_gestures_47_U.mat           61.07%     93.27%      12  2026-04-21
# emg_gestures_48_U.mat           99.29%     93.94%      16  2026-04-21
# emg_gestures_49_U.mat           93.93%     94.44%      18  2026-04-21
# emg_gestures_50_U.mat           94.29%     94.27%      19  2026-04-21
# emg_gestures_51_U.mat           77.14%     93.69%      18  2026-04-21
# emg_gestures_53_U.mat           91.79%     93.85%      20  2026-04-21
# emg_gestures_54_U.mat           90.71%     94.44%      19  2026-04-21
# ====================================================================
# Mean: 80.76%  ±  12.38%  (44 / 44 folds complete)
