# %% [markdown]
# # Feature extraction (Colab)
#
# Extract the 41 single-scalar, channel-major features for every subject.
# Reads `data/processed gestures/{train,eval}` and writes `data/features/{train,eval}`.
# `force=True` re-extracts everything (needed when switching feature format).

# %%
print(5)
# Out:
# 5

# %%
# Install libemg. It pins numpy<2, which downgrades Colab's numpy 2.x in place.
# The downgrade corrupts the *already-loaded* numpy in this kernel, so we MUST
# restart the runtime afterwards — this cell does it automatically.
# !pip install -q libemg

import os
print("libemg installed — restarting runtime so the new numpy loads cleanly...")
print("After it restarts, run the MOUNT and EXTRACTION cells below (skip this one).")
# os.kill(os.getpid(), 9)   # forces Colab to restart the kernel
# Out:
# libemg installed — restarting runtime so the new numpy loads cleanly...
# After it restarts, run the MOUNT and EXTRACTION cells below (skip this one).

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')

# Adjust if your Drive layout differs
BASE = '/content/drive/Othercomputers/My Mac/putEMG prime'
SRC  = os.path.join(BASE, 'src')
if SRC not in sys.path:
    sys.path.insert(0, SRC)

print('base exists:', os.path.isdir(BASE))
print('processed gestures exists:', os.path.isdir(os.path.join(BASE, 'data/processed gestures')))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# base exists: True
# processed gestures exists: True

# %%
from feature_extraction import batch_extract_split_dirs

batch_extract_split_dirs(
    input_root=os.path.join(BASE, 'data/processed gestures'),
    output_root=os.path.join(BASE, 'data/features'),
    force=True,
)
# Out:
# Bluepy not installed...
#
# ...
#   Extracting features: train
# ...
# Found 44 file(s) — 41 features × 24 ch (channel-major)
#
#   [1/44] subject 03: extracting 3614 windows (139 reps × 26 wins)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2253/2661341.py in <cell line: 0>()
#       1 from feature_extraction import batch_extract_split_dirs
#       2
# ----> 3 batch_extract_split_dirs(
#       4     input_root=os.path.join(BASE, 'data/processed gestures'),
#       5     output_root=os.path.join(BASE, 'data/features'),
#
# /content/drive/Othercomputers/My Mac/putEMG prime/src/feature_extraction.py in batch_extract_split_dirs(input_root, output_root, splits, window_size, window_shift, force)
#     105             continue
#     106         print(f"\n{'='*60}\n  Extracting features: {split}\n{'='*60}")
# ...
